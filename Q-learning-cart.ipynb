# %% [markdown]
# # Deep Q-learning
#
# In this notebook, we'll build a neural network that can learn to play games through reinforcement learning. More specifically, we'll use Q-learning to train an agent to play a game called [Cart-Pole](https://gym.openai.com/envs/CartPole-v0). In this game, a freely swinging pole is attached to a cart. The cart can move to the left and right, and the goal is to keep the pole upright as long as possible.
#
# ![Cart-Pole](assets/cart-pole.jpg)
#
# We can simulate this game using [OpenAI Gym](https://gym.openai.com/). First, let's check out how OpenAI Gym works. Then, we'll get into training an agent to play the Cart-Pole game.

# %%
import gym
import tensorflow as tf
import numpy as np
import time

# %% [markdown]
# >**Note:** Make sure you have OpenAI Gym cloned into the same directory with this notebook. I've included `gym` as a submodule, so you can run `git submodule --init --recursive` to pull the contents into the `gym` repo.

# %%
# Create the Cart-Pole game environment
env = gym.make('CartPole-v0')
# Out:
# [2017-08-22 17:17:08,558] Making new env: CartPole-v0

# %% [markdown]
# We interact with the simulation through `env`. To show the simulation running, you can use `env.render()` to render one frame. Passing in an action as an integer to `env.step` will generate the next step in the simulation.  You can see how many actions are possible from `env.action_space` and to get a random action you can use `env.action_space.sample()`. This is general to all Gym games. In the Cart-Pole game, there are two possible actions, moving the cart left or right. So there are two actions we can take, encoded as 0 and 1.
#
# Run the code below to watch the simulation run.

# %%
env.reset()
rewards = []
tic = time.time()
for _ in range(1000):
    env.render()
    state, reward, done, info = env.step(env.action_space.sample()) # take a random action
    rewards.append(reward)
    if done:
        rewards = []
        env.reset()
toc = time.time()
# Shut simulation window after 10s
if toc-tic > 10:
    env.close()
# Out:
# ---------------------------------------------------------------------------
# NoSuchDisplayException                    Traceback (most recent call last)
# <ipython-input-3-50984b18d3f9> in <module>()
#       3 tic = time.time()
#       4 for _ in range(1000):
# ----> 5     env.render()
#       6     state, reward, done, info = env.step(env.action_space.sample()) # take a random action
#       7     rewards.append(reward)
#
# ~/deepQ-learning-openaiGym/gym/gym/core.py in render(self, mode, close)
#     148             elif mode not in modes:
#     149                 raise error.UnsupportedMode('Unsupported rendering mode: {}. (Supported modes for {}: {})'.format(mode, self, modes))
# --> 150         return self._render(mode=mode, close=close)
#     151
#     152     def close(self):
#
# ~/deepQ-learning-openaiGym/gym/gym/core.py in _render(self, mode, close)
#     284
#     285     def _render(self, mode='human', close=False):
# --> 286         return self.env.render(mode, close)
#     287
#     288     def _close(self):
#
# ~/deepQ-learning-openaiGym/gym/gym/core.py in render(self, mode, close)
#     148             elif mode not in modes:
#     149                 raise error.UnsupportedMode('Unsupported rendering mode: {}. (Supported modes for {}: {})'.format(mode, self, modes))
# --> 150         return self._render(mode=mode, close=close)
#     151
#     152     def close(self):
#
# ~/deepQ-learning-openaiGym/gym/gym/envs/classic_control/cartpole.py in _render(self, mode, close)
#     113
#     114         if self.viewer is None:
# --> 115             from gym.envs.classic_control import rendering
#     116             self.viewer = rendering.Viewer(screen_width, screen_height)
#     117             l,r,t,b = -cartwidth/2, cartwidth/2, cartheight/2, -cartheight/2
#
# ~/deepQ-learning-openaiGym/gym/gym/envs/classic_control/rendering.py in <module>()
#      21
#      22 try:
# ---> 23     from pyglet.gl import *
#      24 except ImportError as e:
#      25     reraise(prefix="Error occured while running `from pyglet.gl import *`",suffix="HINT: make sure you have OpenGL install. On Ubuntu, you can run 'apt-get install python-opengl'. If you're running on a server, you may need a virtual frame buffer; something like this should work: 'xvfb-run -s \"-screen 0 1400x900x24\" python <your_script.py>'")
#
# ~/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/pyglet/gl/__init__.py in <module>()
#     234     # trickery is for circular import
#     235     _pyglet.gl = _sys.modules[__name__]
# --> 236     import pyglet.window
#
# ~/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/pyglet/window/__init__.py in <module>()
#    1814 if not _is_epydoc:
#    1815     pyglet.window = sys.modules[__name__]
# -> 1816     gl._create_shadow_window()
#
# ~/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/pyglet/gl/__init__.py in _create_shadow_window()
#     203
#     204     from pyglet.window import Window
# --> 205     _shadow_window = Window(width=1, height=1, visible=False)
#     206     _shadow_window.switch_to()
#     207
#
# ~/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/pyglet/window/xlib/__init__.py in __init__(self, *args, **kwargs)
#     161                     self._event_handlers[message] = func
#     162
# --> 163         super(XlibWindow, self).__init__(*args, **kwargs)
#     164
#     165         global _can_detect_autorepeat
#
# ~/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/pyglet/window/__init__.py in __init__(self, width, height, caption, resizable, style, fullscreen, visible, vsync, display, screen, config, context, mode)
#     491
#     492         if not display:
# --> 493             display = get_platform().get_default_display()
#     494
#     495         if not screen:
#
# ~/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/pyglet/window/__init__.py in get_default_display(self)
#    1763         :rtype: `Display`
#    1764         '''
# -> 1765         return pyglet.canvas.get_display()
#    1766
#    1767 if _is_epydoc:
#
# ~/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/pyglet/canvas/__init__.py in get_display()
#      80
#      81     # Otherwise, create a new display and return it.
# ---> 82     return Display()
#      83
#      84 if _is_epydoc:
#
# ~/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/pyglet/canvas/xlib.py in __init__(self, name, x_screen)
#      81         self._display = xlib.XOpenDisplay(name)
#      82         if not self._display:
# ---> 83             raise NoSuchDisplayException('Cannot connect to "%s"' % name)
#      84
#      85         screen_count = xlib.XScreenCount(self._display)
#
# NoSuchDisplayException: Cannot connect to "None"

# %% [markdown]
# To shut the window showing the simulation, use `env.close()`.

# %% [markdown]
# If you ran the simulation above, we can look at the rewards:

# %%
print(rewards)
# Out:
# [1.0]

# %% [markdown]
# The game resets after the pole has fallen past a certain angle. For each frame while the simulation is running, it returns a reward of 1.0. The longer the game runs, the more reward we get. Then, our network's goal is to maximize the reward by keeping the pole vertical. It will do this by moving the cart to the left and the right.

# %% [markdown]
# ## Q-Network
#
# We train our Q-learning agent using the Bellman Equation:
#
# $$
# Q(s, a) = r + \gamma \max{Q(s', a')}
# $$
#
# where $s$ is a state, $a$ is an action, and $s'$ is the next state from state $s$ and action $a$.
#
# Before we used this equation to learn values for a Q-_table_. However, for this game there are a huge number of states available. The state has four values: the position and velocity of the cart, and the position and velocity of the pole. These are all real-valued numbers, so ignoring floating point precisions, you practically have infinite states. Instead of using a table then, we'll replace it with a neural network that will approximate the Q-table lookup function.
#
# <img src="assets/deep-q-learning.png" width=450px>
#
# Now, our Q value, $Q(s, a)$ is calculated by passing in a state to the network. The output will be Q-values for each available action, with fully connected hidden layers.
#
# <img src="assets/q-network.png" width=550px>
#
#
# As I showed before, we can define our targets for training as $\hat{Q}(s,a) = r + \gamma \max{Q(s', a')}$. Then we update the weights by minimizing $(\hat{Q}(s,a) - Q(s,a))^2$.
#
# For this Cart-Pole game, we have four inputs, one for each value in the state, and two outputs, one for each action. To get $\hat{Q}$, we'll first choose an action, then simulate the game using that action. This will get us the next state, $s'$, and the reward. With that, we can calculate $\hat{Q}$ then pass it back into the $Q$ network to run the optimizer and update the weights.
#
# Below is my implementation of the Q-network. I used two fully connected layers with ReLU activations. Two seems to be good enough, three might be better. Feel free to try it out.

# %%
class QNetwork:
    def __init__(self, learning_rate=0.01, state_size=4, 
                 action_size=2, hidden_size=10, 
                 name='QNetwork'):
        # state inputs to the Q-network
        with tf.variable_scope(name):
            self.inputs_ = tf.placeholder(tf.float32, [None, state_size], name='inputs')
            
            # One hot encode the actions to later choose the Q-value for the action
            self.actions_ = tf.placeholder(tf.int32, [None], name='actions')
            one_hot_actions = tf.one_hot(self.actions_, action_size)
            
            # Target Q values for training
            self.targetQs_ = tf.placeholder(tf.float32, [None], name='target')
            
            # ReLU hidden layers
            self.fc1 = tf.contrib.layers.fully_connected(self.inputs_, hidden_size)
            self.fc2 = tf.contrib.layers.fully_connected(self.fc1, hidden_size)

            # Linear output layer
            self.output = tf.contrib.layers.fully_connected(self.fc2, action_size, 
                                                            activation_fn=None)
                        
            ### Train with loss (targetQ - Q)^2
            # output has length 2, for two actions. This next line chooses
            # one value from output (per row) according to the one-hot encoded actions.
            self.Q = tf.reduce_sum(tf.multiply(self.output, one_hot_actions), axis=1)
            
            self.loss = tf.reduce_mean(tf.square(self.targetQs_ - self.Q))
            self.opt = tf.train.AdamOptimizer(learning_rate).minimize(self.loss)

# %% [markdown]
# ## Experience replay
#
# Reinforcement learning algorithms can have stability issues due to correlations between states. To reduce correlations when training, we can store the agent's experiences and later draw a random mini-batch of those experiences to train on.
#
# Here, we'll create a `Memory` object that will store our experiences, our transitions $<s, a, r, s'>$. This memory will have a maxmium capacity, so we can keep newer experiences in memory while getting rid of older experiences. Then, we'll sample a random mini-batch of transitions $<s, a, r, s'>$ and train on those.
#
# Below, I've implemented a `Memory` object. If you're unfamiliar with `deque`, this is a double-ended queue. You can think of it like a tube open on both sides. You can put objects in either side of the tube. But if it's full, adding anything more will push an object out the other side. This is a great data structure to use for the memory buffer.

# %%
from collections import deque
class Memory():
    def __init__(self, max_size = 1000):
        self.buffer = deque(maxlen=max_size)
    
    def add(self, experience):
        self.buffer.append(experience)
            
    def sample(self, batch_size):
        idx = np.random.choice(np.arange(len(self.buffer)), 
                               size=batch_size, 
                               replace=False)
        return [self.buffer[ii] for ii in idx]

# %% [markdown]
# ## Exploration - Exploitation
#
# To learn about the environment and rules of the game, the agent needs to explore by taking random actions. We'll do this by choosing a random action with some probability $\epsilon$ (epsilon).  That is, with some probability $\epsilon$ the agent will make a random action and with probability $1 - \epsilon$, the agent will choose an action from $Q(s,a)$. This is called an **$\epsilon$-greedy policy**.
#
#
# At first, the agent needs to do a lot of exploring. Later when it has learned more, the agent can favor choosing actions based on what it has learned. This is called _exploitation_. We'll set it up so the agent is more likely to explore early in training, then more likely to exploit later in training.

# %% [markdown]
# ## Q-Learning training algorithm
#
# Putting all this together, we can list out the algorithm we'll use to train the network. We'll train the network in _episodes_. One *episode* is one simulation of the game. For this game, the goal is to keep the pole upright for 195 frames. So we can start a new episode once meeting that goal. The game ends if the pole tilts over too far, or if the cart moves too far the left or right. When a game ends, we'll start a new episode. Now, to train the agent:
#
# * Initialize the memory $D$
# * Initialize the action-value network $Q$ with random weights
# * **For** episode = 1, $M$ **do**
#   * **For** $t$, $T$ **do**
#      * With probability $\epsilon$ select a random action $a_t$, otherwise select $a_t = \mathrm{argmax}_a Q(s,a)$
#      * Execute action $a_t$ in simulator and observe reward $r_{t+1}$ and new state $s_{t+1}$
#      * Store transition $<s_t, a_t, r_{t+1}, s_{t+1}>$ in memory $D$
#      * Sample random mini-batch from $D$: $<s_j, a_j, r_j, s'_j>$
#      * Set $\hat{Q}_j = r_j$ if the episode ends at $j+1$, otherwise set $\hat{Q}_j = r_j + \gamma \max_{a'}{Q(s'_j, a')}$
#      * Make a gradient descent step with loss $(\hat{Q}_j - Q(s_j, a_j))^2$
#   * **endfor**
# * **endfor**

# %% [markdown]
# ## Hyperparameters
#
# One of the more difficult aspects of reinforcememt learning are the large number of hyperparameters. Not only are we tuning the network, but we're tuning the simulation.

# %%
train_episodes = 1000          # max number of episodes to learn from
max_steps = 200                # max steps in an episode
gamma = 0.99                   # future reward discount

# Exploration parameters
explore_start = 1.0            # exploration probability at start
explore_stop = 0.01            # minimum exploration probability 
decay_rate = 0.0001            # exponential decay rate for exploration prob

# Network parameters
hidden_size = 64               # number of units in each Q-network hidden layer
learning_rate = 0.0001         # Q-network learning rate

# Memory parameters
memory_size = 10000            # memory capacity
batch_size = 20                # experience mini-batch size
pretrain_length = batch_size   # number experiences to pretrain the memory

# %%
tf.reset_default_graph()
mainQN = QNetwork(name='main', hidden_size=hidden_size, learning_rate=learning_rate)

# %% [markdown]
# ## Populate the experience memory
#
# Here I'm re-initializing the simulation and pre-populating the memory. The agent is taking random actions and storing the transitions in memory. This will help the agent with exploring the game.

# %%
# Initialize the simulation
env.reset()
# Take one random step to get the pole and cart moving
state, reward, done, _ = env.step(env.action_space.sample())

memory = Memory(max_size=memory_size)

# Make a bunch of random actions and store the experiences
for ii in range(pretrain_length):
    # Uncomment the line below to watch the simulation
    # env.render()

    # Make a random action
    action = env.action_space.sample()
    next_state, reward, done, _ = env.step(action)

    if done:
        # The simulation fails so no next state
        next_state = np.zeros(state.shape)
        # Add experience to memory
        memory.add((state, action, reward, next_state))
        
        # Start new episode
        env.reset()
        # Take one random step to get the pole and cart moving
        state, reward, done, _ = env.step(env.action_space.sample())
    else:
        # Add experience to memory
        memory.add((state, action, reward, next_state))
        state = next_state

# %% [markdown]
# ## Training
#
# Below we'll train our agent. If you want to watch it train, uncomment the `env.render()` line. This is slow because it's rendering the frames slower than the network can train. But, it's cool to watch the agent get better at the game.

# %%
# Now train with experiences
saver = tf.train.Saver()
rewards_list = []
with tf.Session() as sess:
    # Initialize variables
    sess.run(tf.global_variables_initializer())
    
    step = 0
    for ep in range(1, train_episodes):
        total_reward = 0
        t = 0
        while t < max_steps:
            step += 1
            # Uncomment this next line to watch the training
            # env.render() 
            
            # Explore or Exploit
            explore_p = explore_stop + (explore_start - explore_stop)*np.exp(-decay_rate*step) 
            if explore_p > np.random.rand():
                # Make a random action
                action = env.action_space.sample()
            else:
                # Get action from Q-network
                feed = {mainQN.inputs_: state.reshape((1, *state.shape))}
                Qs = sess.run(mainQN.output, feed_dict=feed)
                action = np.argmax(Qs)
            
            # Take action, get new state and reward
            next_state, reward, done, _ = env.step(action)
    
            total_reward += reward
            
            if done:
                # the episode ends so no next state
                next_state = np.zeros(state.shape)
                t = max_steps
                
                print('Episode: {}'.format(ep),
                      'Total reward: {}'.format(total_reward),
                      'Training loss: {:.4f}'.format(loss),
                      'Explore P: {:.4f}'.format(explore_p))
                rewards_list.append((ep, total_reward))
                
                # Add experience to memory
                memory.add((state, action, reward, next_state))
                
                # Start new episode
                env.reset()
                # Take one random step to get the pole and cart moving
                state, reward, done, _ = env.step(env.action_space.sample())

            else:
                # Add experience to memory
                memory.add((state, action, reward, next_state))
                state = next_state
                t += 1
            
            # Sample mini-batch from memory
            batch = memory.sample(batch_size)
            states = np.array([each[0] for each in batch])
            actions = np.array([each[1] for each in batch])
            rewards = np.array([each[2] for each in batch])
            next_states = np.array([each[3] for each in batch])
            
            # Train network
            target_Qs = sess.run(mainQN.output, feed_dict={mainQN.inputs_: next_states})
            
            # Set target_Qs to 0 for states where episode ends
            episode_ends = (next_states == np.zeros(states[0].shape)).all(axis=1)
            target_Qs[episode_ends] = (0, 0)
            
            targets = rewards + gamma * np.max(target_Qs, axis=1)

            loss, _ = sess.run([mainQN.loss, mainQN.opt],
                                feed_dict={mainQN.inputs_: states,
                                           mainQN.targetQs_: targets,
                                           mainQN.actions_: actions})
        
    saver.save(sess, "checkpoints/cartpole.ckpt")
# Out:
# Episode: 1 Total reward: 9.0 Training loss: 1.1238 Explore P: 0.9991
# Episode: 2 Total reward: 53.0 Training loss: 1.1185 Explore P: 0.9939
# Episode: 3 Total reward: 18.0 Training loss: 1.0416 Explore P: 0.9921
# Episode: 4 Total reward: 49.0 Training loss: 1.0998 Explore P: 0.9873
# Episode: 5 Total reward: 17.0 Training loss: 1.2988 Explore P: 0.9857
# Episode: 6 Total reward: 27.0 Training loss: 1.2824 Explore P: 0.9830
# Episode: 7 Total reward: 25.0 Training loss: 1.1572 Explore P: 0.9806
# Episode: 8 Total reward: 32.0 Training loss: 1.0587 Explore P: 0.9775
# Episode: 9 Total reward: 12.0 Training loss: 1.0227 Explore P: 0.9763
# Episode: 10 Total reward: 16.0 Training loss: 1.0042 Explore P: 0.9748
# Episode: 11 Total reward: 10.0 Training loss: 1.1503 Explore P: 0.9738
# Episode: 12 Total reward: 21.0 Training loss: 0.9827 Explore P: 0.9718
# Episode: 13 Total reward: 27.0 Training loss: 1.0440 Explore P: 0.9692
# Episode: 14 Total reward: 16.0 Training loss: 1.1559 Explore P: 0.9677
# Episode: 15 Total reward: 31.0 Training loss: 1.1928 Explore P: 0.9647
# Episode: 16 Total reward: 42.0 Training loss: 1.4626 Explore P: 0.9607
# Episode: 17 Total reward: 11.0 Training loss: 1.0365 Explore P: 0.9597
# Episode: 18 Total reward: 32.0 Training loss: 1.9716 Explore P: 0.9566
# Episode: 19 Total reward: 20.0 Training loss: 1.3626 Explore P: 0.9547
# Episode: 20 Total reward: 20.0 Training loss: 2.3926 Explore P: 0.9528
# Episode: 21 Total reward: 9.0 Training loss: 1.8070 Explore P: 0.9520
# Episode: 22 Total reward: 12.0 Training loss: 1.8949 Explore P: 0.9509
# Episode: 23 Total reward: 18.0 Training loss: 2.7380 Explore P: 0.9492
# Episode: 24 Total reward: 10.0 Training loss: 1.0527 Explore P: 0.9482
# Episode: 25 Total reward: 38.0 Training loss: 2.5012 Explore P: 0.9447
# Episode: 26 Total reward: 42.0 Training loss: 2.5394 Explore P: 0.9408
# Episode: 27 Total reward: 18.0 Training loss: 1.5467 Explore P: 0.9391
# Episode: 28 Total reward: 16.0 Training loss: 1.3363 Explore P: 0.9376
# Episode: 29 Total reward: 25.0 Training loss: 2.6058 Explore P: 0.9353
# Episode: 30 Total reward: 12.0 Training loss: 4.1158 Explore P: 0.9342
# Episode: 31 Total reward: 14.0 Training loss: 3.5124 Explore P: 0.9329
# Episode: 32 Total reward: 17.0 Training loss: 4.2593 Explore P: 0.9313
# Episode: 33 Total reward: 58.0 Training loss: 2.2496 Explore P: 0.9260
# Episode: 34 Total reward: 18.0 Training loss: 3.0125 Explore P: 0.9243
# Episode: 35 Total reward: 12.0 Training loss: 3.2668 Explore P: 0.9232
# Episode: 36 Total reward: 31.0 Training loss: 5.4480 Explore P: 0.9204
# Episode: 37 Total reward: 13.0 Training loss: 6.4720 Explore P: 0.9192
# Episode: 38 Total reward: 12.0 Training loss: 2.2752 Explore P: 0.9181
# Episode: 39 Total reward: 16.0 Training loss: 18.0086 Explore P: 0.9167
# Episode: 40 Total reward: 9.0 Training loss: 3.6689 Explore P: 0.9159
# Episode: 41 Total reward: 23.0 Training loss: 3.9978 Explore P: 0.9138
# Episode: 42 Total reward: 16.0 Training loss: 3.7910 Explore P: 0.9124
# Episode: 43 Total reward: 10.0 Training loss: 6.0658 Explore P: 0.9115
# Episode: 44 Total reward: 17.0 Training loss: 4.7389 Explore P: 0.9099
# Episode: 45 Total reward: 19.0 Training loss: 8.6970 Explore P: 0.9082
# Episode: 46 Total reward: 19.0 Training loss: 10.7478 Explore P: 0.9065
# Episode: 47 Total reward: 9.0 Training loss: 14.9147 Explore P: 0.9057
# Episode: 48 Total reward: 16.0 Training loss: 28.0916 Explore P: 0.9043
# Episode: 49 Total reward: 35.0 Training loss: 3.7961 Explore P: 0.9011
# Episode: 50 Total reward: 15.0 Training loss: 5.8021 Explore P: 0.8998
# Episode: 51 Total reward: 15.0 Training loss: 17.7128 Explore P: 0.8985
# Episode: 52 Total reward: 12.0 Training loss: 5.1679 Explore P: 0.8974
# Episode: 53 Total reward: 26.0 Training loss: 3.6962 Explore P: 0.8951
# Episode: 54 Total reward: 21.0 Training loss: 4.9914 Explore P: 0.8932
# Episode: 55 Total reward: 58.0 Training loss: 8.4593 Explore P: 0.8881
# Episode: 56 Total reward: 10.0 Training loss: 23.7937 Explore P: 0.8873
# Episode: 57 Total reward: 22.0 Training loss: 16.4113 Explore P: 0.8853
# Episode: 58 Total reward: 14.0 Training loss: 22.1555 Explore P: 0.8841
# Episode: 59 Total reward: 21.0 Training loss: 8.0394 Explore P: 0.8823
# Episode: 60 Total reward: 13.0 Training loss: 35.7501 Explore P: 0.8811
# Episode: 61 Total reward: 11.0 Training loss: 9.6859 Explore P: 0.8802
# Episode: 62 Total reward: 21.0 Training loss: 68.6910 Explore P: 0.8784
# Episode: 63 Total reward: 11.0 Training loss: 96.2654 Explore P: 0.8774
# Episode: 64 Total reward: 15.0 Training loss: 11.0730 Explore P: 0.8761
# Episode: 65 Total reward: 16.0 Training loss: 81.6840 Explore P: 0.8747
# Episode: 66 Total reward: 13.0 Training loss: 36.5317 Explore P: 0.8736
# Episode: 67 Total reward: 10.0 Training loss: 13.9124 Explore P: 0.8727
# Episode: 68 Total reward: 14.0 Training loss: 13.0852 Explore P: 0.8715
# Episode: 69 Total reward: 29.0 Training loss: 184.3136 Explore P: 0.8690
# Episode: 70 Total reward: 22.0 Training loss: 10.0630 Explore P: 0.8671
# Episode: 71 Total reward: 26.0 Training loss: 74.5932 Explore P: 0.8649
# Episode: 72 Total reward: 16.0 Training loss: 14.8396 Explore P: 0.8636
# Episode: 73 Total reward: 41.0 Training loss: 148.3133 Explore P: 0.8601
# Episode: 74 Total reward: 8.0 Training loss: 86.0318 Explore P: 0.8594
# Episode: 75 Total reward: 64.0 Training loss: 43.9035 Explore P: 0.8540
# Episode: 76 Total reward: 55.0 Training loss: 130.4891 Explore P: 0.8493
# Episode: 77 Total reward: 14.0 Training loss: 93.0438 Explore P: 0.8482
# Episode: 78 Total reward: 14.0 Training loss: 17.2068 Explore P: 0.8470
# Episode: 79 Total reward: 17.0 Training loss: 194.3290 Explore P: 0.8456
# Episode: 80 Total reward: 11.0 Training loss: 50.8473 Explore P: 0.8446
# Episode: 81 Total reward: 9.0 Training loss: 80.6874 Explore P: 0.8439
# Episode: 82 Total reward: 17.0 Training loss: 71.3152 Explore P: 0.8425
# Episode: 83 Total reward: 29.0 Training loss: 25.0052 Explore P: 0.8401
# Episode: 84 Total reward: 9.0 Training loss: 201.9630 Explore P: 0.8393
# Episode: 85 Total reward: 13.0 Training loss: 94.1785 Explore P: 0.8382
# Episode: 86 Total reward: 21.0 Training loss: 345.9400 Explore P: 0.8365
# Episode: 87 Total reward: 33.0 Training loss: 312.5992 Explore P: 0.8338
# Episode: 88 Total reward: 11.0 Training loss: 101.0104 Explore P: 0.8329
# Episode: 89 Total reward: 25.0 Training loss: 226.7043 Explore P: 0.8308
# Episode: 90 Total reward: 16.0 Training loss: 110.2942 Explore P: 0.8295
# Episode: 91 Total reward: 12.0 Training loss: 21.7265 Explore P: 0.8285
# Episode: 92 Total reward: 20.0 Training loss: 145.1382 Explore P: 0.8269
# Episode: 93 Total reward: 25.0 Training loss: 446.2388 Explore P: 0.8249
# Episode: 94 Total reward: 12.0 Training loss: 65.1790 Explore P: 0.8239
# Episode: 95 Total reward: 14.0 Training loss: 94.2641 Explore P: 0.8227
# Episode: 96 Total reward: 9.0 Training loss: 240.1046 Explore P: 0.8220
# Episode: 97 Total reward: 18.0 Training loss: 19.6355 Explore P: 0.8205
# Episode: 98 Total reward: 17.0 Training loss: 69.1685 Explore P: 0.8192
# Episode: 99 Total reward: 14.0 Training loss: 66.8087 Explore P: 0.8180
# Episode: 100 Total reward: 18.0 Training loss: 108.0471 Explore P: 0.8166
# Episode: 101 Total reward: 13.0 Training loss: 14.1905 Explore P: 0.8155
# Episode: 102 Total reward: 33.0 Training loss: 16.1964 Explore P: 0.8129
# Episode: 103 Total reward: 13.0 Training loss: 17.8236 Explore P: 0.8118
# Episode: 104 Total reward: 12.0 Training loss: 14.3074 Explore P: 0.8109
# Episode: 105 Total reward: 24.0 Training loss: 147.4674 Explore P: 0.8090
# Episode: 106 Total reward: 16.0 Training loss: 14.4578 Explore P: 0.8077
# Episode: 107 Total reward: 15.0 Training loss: 197.8705 Explore P: 0.8065
# Episode: 108 Total reward: 13.0 Training loss: 89.5360 Explore P: 0.8054
# Episode: 109 Total reward: 10.0 Training loss: 438.3326 Explore P: 0.8047
# Episode: 110 Total reward: 42.0 Training loss: 123.3724 Explore P: 0.8013
# Episode: 111 Total reward: 21.0 Training loss: 267.5888 Explore P: 0.7997
# Episode: 112 Total reward: 21.0 Training loss: 218.3927 Explore P: 0.7980
# Episode: 113 Total reward: 16.0 Training loss: 323.7520 Explore P: 0.7967
# Episode: 114 Total reward: 40.0 Training loss: 17.2286 Explore P: 0.7936
# Episode: 115 Total reward: 24.0 Training loss: 189.0238 Explore P: 0.7917
# Episode: 116 Total reward: 14.0 Training loss: 332.5872 Explore P: 0.7906
# Episode: 117 Total reward: 23.0 Training loss: 116.2790 Explore P: 0.7888
# Episode: 118 Total reward: 27.0 Training loss: 10.1849 Explore P: 0.7867
# Episode: 119 Total reward: 15.0 Training loss: 179.7623 Explore P: 0.7856
# Episode: 120 Total reward: 10.0 Training loss: 174.3480 Explore P: 0.7848
# Episode: 121 Total reward: 30.0 Training loss: 121.3189 Explore P: 0.7825
# Episode: 122 Total reward: 62.0 Training loss: 9.0897 Explore P: 0.7777
# Episode: 123 Total reward: 7.0 Training loss: 117.4221 Explore P: 0.7772
# Episode: 124 Total reward: 11.0 Training loss: 9.9607 Explore P: 0.7763
# Episode: 125 Total reward: 15.0 Training loss: 9.6020 Explore P: 0.7752
# Episode: 126 Total reward: 21.0 Training loss: 6.2521 Explore P: 0.7736
# Episode: 127 Total reward: 10.0 Training loss: 374.0794 Explore P: 0.7728
# Episode: 128 Total reward: 17.0 Training loss: 137.4924 Explore P: 0.7715
# Episode: 129 Total reward: 16.0 Training loss: 11.5074 Explore P: 0.7703
# Episode: 130 Total reward: 15.0 Training loss: 121.4856 Explore P: 0.7692
# Episode: 131 Total reward: 17.0 Training loss: 9.5852 Explore P: 0.7679
# Episode: 132 Total reward: 9.0 Training loss: 115.8215 Explore P: 0.7672
# Episode: 133 Total reward: 14.0 Training loss: 9.1920 Explore P: 0.7661
# Episode: 134 Total reward: 8.0 Training loss: 106.7088 Explore P: 0.7655
# Episode: 135 Total reward: 21.0 Training loss: 9.7460 Explore P: 0.7639
# Episode: 136 Total reward: 14.0 Training loss: 118.3573 Explore P: 0.7629
# Episode: 137 Total reward: 18.0 Training loss: 5.7121 Explore P: 0.7615
# Episode: 138 Total reward: 12.0 Training loss: 6.4940 Explore P: 0.7606
# Episode: 139 Total reward: 12.0 Training loss: 141.1788 Explore P: 0.7597
# Episode: 140 Total reward: 28.0 Training loss: 477.6887 Explore P: 0.7576
# Episode: 141 Total reward: 9.0 Training loss: 6.6526 Explore P: 0.7570
# Episode: 142 Total reward: 17.0 Training loss: 4.8520 Explore P: 0.7557
# Episode: 143 Total reward: 22.0 Training loss: 135.7132 Explore P: 0.7540
# Episode: 144 Total reward: 10.0 Training loss: 100.5526 Explore P: 0.7533
# Episode: 145 Total reward: 38.0 Training loss: 125.8494 Explore P: 0.7505
# Episode: 146 Total reward: 21.0 Training loss: 131.6272 Explore P: 0.7489
# Episode: 147 Total reward: 38.0 Training loss: 6.7952 Explore P: 0.7461
# Episode: 148 Total reward: 9.0 Training loss: 232.1068 Explore P: 0.7455
# Episode: 149 Total reward: 21.0 Training loss: 182.7406 Explore P: 0.7439
# Episode: 150 Total reward: 18.0 Training loss: 221.4303 Explore P: 0.7426
# Episode: 151 Total reward: 15.0 Training loss: 86.1814 Explore P: 0.7415
# Episode: 152 Total reward: 9.0 Training loss: 126.9391 Explore P: 0.7408
# Episode: 153 Total reward: 8.0 Training loss: 269.9038 Explore P: 0.7403
# Episode: 154 Total reward: 12.0 Training loss: 101.9986 Explore P: 0.7394
# Episode: 155 Total reward: 12.0 Training loss: 2.3573 Explore P: 0.7385
# Episode: 156 Total reward: 19.0 Training loss: 195.7372 Explore P: 0.7371
# Episode: 157 Total reward: 24.0 Training loss: 78.9929 Explore P: 0.7354
# Episode: 158 Total reward: 12.0 Training loss: 103.5450 Explore P: 0.7345
# Episode: 159 Total reward: 22.0 Training loss: 3.8800 Explore P: 0.7329
# Episode: 160 Total reward: 15.0 Training loss: 194.3236 Explore P: 0.7318
# Episode: 161 Total reward: 18.0 Training loss: 2.0437 Explore P: 0.7305
# Episode: 162 Total reward: 17.0 Training loss: 250.0646 Explore P: 0.7293
# Episode: 163 Total reward: 11.0 Training loss: 3.2456 Explore P: 0.7285
# Episode: 164 Total reward: 32.0 Training loss: 94.1595 Explore P: 0.7262
# Episode: 165 Total reward: 15.0 Training loss: 117.0515 Explore P: 0.7252
# Episode: 166 Total reward: 10.0 Training loss: 65.4307 Explore P: 0.7244
# Episode: 167 Total reward: 12.0 Training loss: 2.9165 Explore P: 0.7236
# Episode: 168 Total reward: 9.0 Training loss: 2.8311 Explore P: 0.7229
# Episode: 169 Total reward: 17.0 Training loss: 75.2040 Explore P: 0.7217
# Episode: 170 Total reward: 9.0 Training loss: 0.9943 Explore P: 0.7211
# Episode: 171 Total reward: 15.0 Training loss: 1.7212 Explore P: 0.7200
# Episode: 172 Total reward: 20.0 Training loss: 163.4155 Explore P: 0.7186
# Episode: 173 Total reward: 13.0 Training loss: 66.9228 Explore P: 0.7177
# Episode: 174 Total reward: 10.0 Training loss: 122.3387 Explore P: 0.7170
# Episode: 175 Total reward: 10.0 Training loss: 71.2091 Explore P: 0.7163
# Episode: 176 Total reward: 9.0 Training loss: 1.9882 Explore P: 0.7156
# Episode: 177 Total reward: 10.0 Training loss: 189.8073 Explore P: 0.7149
# Episode: 178 Total reward: 23.0 Training loss: 140.8708 Explore P: 0.7133
# Episode: 179 Total reward: 8.0 Training loss: 185.0283 Explore P: 0.7128
# Episode: 180 Total reward: 11.0 Training loss: 1.7404 Explore P: 0.7120
# Episode: 181 Total reward: 12.0 Training loss: 1.9235 Explore P: 0.7111
# Episode: 182 Total reward: 16.0 Training loss: 1.8516 Explore P: 0.7100
# Episode: 183 Total reward: 15.0 Training loss: 2.0249 Explore P: 0.7090
# Episode: 184 Total reward: 9.0 Training loss: 203.0645 Explore P: 0.7083
# Episode: 185 Total reward: 13.0 Training loss: 156.8889 Explore P: 0.7074
# Episode: 186 Total reward: 10.0 Training loss: 189.9022 Explore P: 0.7067
# Episode: 187 Total reward: 11.0 Training loss: 114.1939 Explore P: 0.7060
# Episode: 188 Total reward: 15.0 Training loss: 2.0142 Explore P: 0.7049
# Episode: 189 Total reward: 8.0 Training loss: 55.1665 Explore P: 0.7044
# Episode: 190 Total reward: 12.0 Training loss: 1.6591 Explore P: 0.7035
# Episode: 191 Total reward: 13.0 Training loss: 56.0600 Explore P: 0.7026
# Episode: 192 Total reward: 16.0 Training loss: 44.4692 Explore P: 0.7015
# Episode: 193 Total reward: 11.0 Training loss: 2.0015 Explore P: 0.7008
# Episode: 194 Total reward: 10.0 Training loss: 1.7804 Explore P: 0.7001
# Episode: 195 Total reward: 15.0 Training loss: 3.2419 Explore P: 0.6990
# Episode: 196 Total reward: 17.0 Training loss: 1.8050 Explore P: 0.6979
# Episode: 197 Total reward: 9.0 Training loss: 62.6505 Explore P: 0.6973
# Episode: 198 Total reward: 13.0 Training loss: 88.0133 Explore P: 0.6964
# Episode: 199 Total reward: 11.0 Training loss: 1.9943 Explore P: 0.6956
# Episode: 200 Total reward: 13.0 Training loss: 52.2792 Explore P: 0.6947
# Episode: 201 Total reward: 15.0 Training loss: 1.3631 Explore P: 0.6937
# Episode: 202 Total reward: 11.0 Training loss: 2.4076 Explore P: 0.6929
# Episode: 203 Total reward: 13.0 Training loss: 47.8843 Explore P: 0.6921
# Episode: 204 Total reward: 12.0 Training loss: 2.6425 Explore P: 0.6912
# Episode: 205 Total reward: 9.0 Training loss: 2.1367 Explore P: 0.6906
# Episode: 206 Total reward: 26.0 Training loss: 49.3875 Explore P: 0.6889
# Episode: 207 Total reward: 10.0 Training loss: 117.7728 Explore P: 0.6882
# Episode: 208 Total reward: 10.0 Training loss: 1.2315 Explore P: 0.6875
# Episode: 209 Total reward: 20.0 Training loss: 190.6735 Explore P: 0.6861
# Episode: 210 Total reward: 14.0 Training loss: 2.9965 Explore P: 0.6852
# Episode: 211 Total reward: 38.0 Training loss: 193.9434 Explore P: 0.6826
# Episode: 212 Total reward: 9.0 Training loss: 1.8870 Explore P: 0.6820
# Episode: 213 Total reward: 36.0 Training loss: 92.5766 Explore P: 0.6796
# Episode: 214 Total reward: 12.0 Training loss: 81.4585 Explore P: 0.6788
# Episode: 215 Total reward: 10.0 Training loss: 2.0344 Explore P: 0.6781
# Episode: 216 Total reward: 18.0 Training loss: 3.4422 Explore P: 0.6769
# Episode: 217 Total reward: 10.0 Training loss: 87.3148 Explore P: 0.6763
# Episode: 218 Total reward: 14.0 Training loss: 224.6152 Explore P: 0.6753
# Episode: 219 Total reward: 9.0 Training loss: 76.5576 Explore P: 0.6747
# Episode: 220 Total reward: 11.0 Training loss: 43.9450 Explore P: 0.6740
# Episode: 221 Total reward: 7.0 Training loss: 113.7872 Explore P: 0.6736
# Episode: 222 Total reward: 16.0 Training loss: 35.0681 Explore P: 0.6725
# Episode: 223 Total reward: 10.0 Training loss: 37.9454 Explore P: 0.6718
# Episode: 224 Total reward: 11.0 Training loss: 1.8232 Explore P: 0.6711
# Episode: 225 Total reward: 11.0 Training loss: 2.4329 Explore P: 0.6704
# Episode: 226 Total reward: 24.0 Training loss: 35.0029 Explore P: 0.6688
# Episode: 227 Total reward: 19.0 Training loss: 37.7767 Explore P: 0.6675
# Episode: 228 Total reward: 9.0 Training loss: 1.2426 Explore P: 0.6669
# Episode: 229 Total reward: 11.0 Training loss: 81.8556 Explore P: 0.6662
# Episode: 230 Total reward: 14.0 Training loss: 248.6554 Explore P: 0.6653
# Episode: 231 Total reward: 17.0 Training loss: 108.2264 Explore P: 0.6642
# Episode: 232 Total reward: 16.0 Training loss: 98.7024 Explore P: 0.6631
# Episode: 233 Total reward: 21.0 Training loss: 3.4592 Explore P: 0.6618
# Episode: 234 Total reward: 14.0 Training loss: 29.7686 Explore P: 0.6609
# Episode: 235 Total reward: 18.0 Training loss: 57.2914 Explore P: 0.6597
# Episode: 236 Total reward: 18.0 Training loss: 1.8764 Explore P: 0.6585
# Episode: 237 Total reward: 11.0 Training loss: 71.3079 Explore P: 0.6578
# Episode: 238 Total reward: 13.0 Training loss: 2.9739 Explore P: 0.6570
# Episode: 239 Total reward: 28.0 Training loss: 2.4507 Explore P: 0.6552
# Episode: 240 Total reward: 33.0 Training loss: 172.7514 Explore P: 0.6530
# Episode: 241 Total reward: 10.0 Training loss: 3.3217 Explore P: 0.6524
# Episode: 242 Total reward: 11.0 Training loss: 2.7145 Explore P: 0.6517
# Episode: 243 Total reward: 8.0 Training loss: 34.8975 Explore P: 0.6512
# Episode: 244 Total reward: 9.0 Training loss: 34.4117 Explore P: 0.6506
# Episode: 245 Total reward: 12.0 Training loss: 25.8802 Explore P: 0.6498
# Episode: 246 Total reward: 10.0 Training loss: 30.7548 Explore P: 0.6492
# Episode: 247 Total reward: 13.0 Training loss: 2.3831 Explore P: 0.6484
# Episode: 248 Total reward: 18.0 Training loss: 30.2033 Explore P: 0.6472
# Episode: 249 Total reward: 15.0 Training loss: 32.7383 Explore P: 0.6463
# Episode: 250 Total reward: 26.0 Training loss: 3.8957 Explore P: 0.6446
# Episode: 251 Total reward: 23.0 Training loss: 110.2929 Explore P: 0.6431
# Episode: 252 Total reward: 17.0 Training loss: 29.2444 Explore P: 0.6421
# Episode: 253 Total reward: 10.0 Training loss: 29.0058 Explore P: 0.6414
# Episode: 254 Total reward: 27.0 Training loss: 110.7248 Explore P: 0.6397
# Episode: 255 Total reward: 10.0 Training loss: 139.8862 Explore P: 0.6391
# Episode: 256 Total reward: 12.0 Training loss: 39.9412 Explore P: 0.6384
# Episode: 257 Total reward: 10.0 Training loss: 94.6737 Explore P: 0.6377
# Episode: 258 Total reward: 26.0 Training loss: 161.6620 Explore P: 0.6361
# Episode: 259 Total reward: 8.0 Training loss: 88.5681 Explore P: 0.6356
# Episode: 260 Total reward: 9.0 Training loss: 81.9497 Explore P: 0.6350
# Episode: 261 Total reward: 16.0 Training loss: 112.1167 Explore P: 0.6340
# Episode: 262 Total reward: 16.0 Training loss: 124.6566 Explore P: 0.6330
# Episode: 263 Total reward: 12.0 Training loss: 66.7900 Explore P: 0.6323
# Episode: 264 Total reward: 19.0 Training loss: 2.2049 Explore P: 0.6311
# Episode: 265 Total reward: 11.0 Training loss: 3.0528 Explore P: 0.6304
# Episode: 266 Total reward: 16.0 Training loss: 3.0211 Explore P: 0.6294
# Episode: 267 Total reward: 16.0 Training loss: 64.6770 Explore P: 0.6284
# Episode: 268 Total reward: 12.0 Training loss: 2.9604 Explore P: 0.6277
# Episode: 269 Total reward: 12.0 Training loss: 89.5028 Explore P: 0.6270
# Episode: 270 Total reward: 42.0 Training loss: 86.1672 Explore P: 0.6244
# Episode: 271 Total reward: 11.0 Training loss: 132.5523 Explore P: 0.6237
# Episode: 272 Total reward: 16.0 Training loss: 2.1784 Explore P: 0.6227
# Episode: 273 Total reward: 14.0 Training loss: 25.4545 Explore P: 0.6219
# Episode: 274 Total reward: 12.0 Training loss: 91.3136 Explore P: 0.6211
# Episode: 275 Total reward: 22.0 Training loss: 73.6589 Explore P: 0.6198
# Episode: 276 Total reward: 10.0 Training loss: 94.6463 Explore P: 0.6192
# Episode: 277 Total reward: 17.0 Training loss: 24.7655 Explore P: 0.6181
# Episode: 278 Total reward: 15.0 Training loss: 36.3889 Explore P: 0.6172
# Episode: 279 Total reward: 30.0 Training loss: 82.7375 Explore P: 0.6154
# Episode: 280 Total reward: 23.0 Training loss: 101.7260 Explore P: 0.6140
# Episode: 281 Total reward: 9.0 Training loss: 59.8940 Explore P: 0.6135
# Episode: 282 Total reward: 12.0 Training loss: 23.3108 Explore P: 0.6128
# Episode: 283 Total reward: 14.0 Training loss: 81.4698 Explore P: 0.6119
# Episode: 284 Total reward: 17.0 Training loss: 2.5498 Explore P: 0.6109
# Episode: 285 Total reward: 9.0 Training loss: 74.1559 Explore P: 0.6103
# Episode: 286 Total reward: 12.0 Training loss: 23.5535 Explore P: 0.6096
# Episode: 287 Total reward: 10.0 Training loss: 24.0642 Explore P: 0.6090
# Episode: 288 Total reward: 11.0 Training loss: 100.6902 Explore P: 0.6084
# Episode: 289 Total reward: 26.0 Training loss: 4.2518 Explore P: 0.6068
# Episode: 290 Total reward: 22.0 Training loss: 2.0994 Explore P: 0.6055
# Episode: 291 Total reward: 10.0 Training loss: 2.0678 Explore P: 0.6049
# Episode: 292 Total reward: 8.0 Training loss: 24.6979 Explore P: 0.6044
# Episode: 293 Total reward: 13.0 Training loss: 2.5280 Explore P: 0.6037
# Episode: 294 Total reward: 9.0 Training loss: 77.7995 Explore P: 0.6031
# Episode: 295 Total reward: 11.0 Training loss: 24.5148 Explore P: 0.6025
# Episode: 296 Total reward: 27.0 Training loss: 2.8658 Explore P: 0.6009
# Episode: 297 Total reward: 14.0 Training loss: 2.4662 Explore P: 0.6000
# Episode: 298 Total reward: 13.0 Training loss: 24.1583 Explore P: 0.5993
# Episode: 299 Total reward: 11.0 Training loss: 1.9969 Explore P: 0.5986
# Episode: 300 Total reward: 25.0 Training loss: 2.2566 Explore P: 0.5972
# Episode: 301 Total reward: 11.0 Training loss: 20.3958 Explore P: 0.5965
# Episode: 302 Total reward: 14.0 Training loss: 63.3875 Explore P: 0.5957
# Episode: 303 Total reward: 17.0 Training loss: 116.9436 Explore P: 0.5947
# Episode: 304 Total reward: 15.0 Training loss: 73.9501 Explore P: 0.5938
# Episode: 305 Total reward: 23.0 Training loss: 47.2113 Explore P: 0.5925
# Episode: 306 Total reward: 14.0 Training loss: 1.9900 Explore P: 0.5917
# Episode: 307 Total reward: 14.0 Training loss: 21.9259 Explore P: 0.5909
# Episode: 308 Total reward: 28.0 Training loss: 1.6293 Explore P: 0.5892
# Episode: 309 Total reward: 8.0 Training loss: 1.6462 Explore P: 0.5888
# Episode: 310 Total reward: 8.0 Training loss: 82.1675 Explore P: 0.5883
# Episode: 311 Total reward: 14.0 Training loss: 1.6973 Explore P: 0.5875
# Episode: 312 Total reward: 15.0 Training loss: 47.5393 Explore P: 0.5866
# Episode: 313 Total reward: 32.0 Training loss: 24.2002 Explore P: 0.5848
# Episode: 314 Total reward: 12.0 Training loss: 1.9520 Explore P: 0.5841
# Episode: 315 Total reward: 11.0 Training loss: 77.3859 Explore P: 0.5835
# Episode: 316 Total reward: 9.0 Training loss: 64.3694 Explore P: 0.5830
# Episode: 317 Total reward: 8.0 Training loss: 2.0848 Explore P: 0.5825
# Episode: 318 Total reward: 19.0 Training loss: 55.4315 Explore P: 0.5814
# Episode: 319 Total reward: 36.0 Training loss: 21.5131 Explore P: 0.5794
# Episode: 320 Total reward: 14.0 Training loss: 2.0780 Explore P: 0.5786
# Episode: 321 Total reward: 17.0 Training loss: 127.3962 Explore P: 0.5776
# Episode: 322 Total reward: 13.0 Training loss: 44.9467 Explore P: 0.5769
# Episode: 323 Total reward: 7.0 Training loss: 58.0838 Explore P: 0.5765
# Episode: 324 Total reward: 11.0 Training loss: 18.7665 Explore P: 0.5758
# Episode: 325 Total reward: 17.0 Training loss: 64.8787 Explore P: 0.5749
# Episode: 326 Total reward: 21.0 Training loss: 19.5800 Explore P: 0.5737
# Episode: 327 Total reward: 8.0 Training loss: 1.7101 Explore P: 0.5732
# Episode: 328 Total reward: 9.0 Training loss: 125.3571 Explore P: 0.5727
# Episode: 329 Total reward: 15.0 Training loss: 45.7458 Explore P: 0.5719
# Episode: 330 Total reward: 12.0 Training loss: 42.6444 Explore P: 0.5712
# Episode: 331 Total reward: 11.0 Training loss: 1.0869 Explore P: 0.5706
# Episode: 332 Total reward: 12.0 Training loss: 118.2810 Explore P: 0.5699
# Episode: 333 Total reward: 9.0 Training loss: 40.1739 Explore P: 0.5694
# Episode: 334 Total reward: 15.0 Training loss: 43.2112 Explore P: 0.5686
# Episode: 335 Total reward: 13.0 Training loss: 1.9861 Explore P: 0.5679
# Episode: 336 Total reward: 18.0 Training loss: 60.3427 Explore P: 0.5669
# Episode: 337 Total reward: 15.0 Training loss: 94.1191 Explore P: 0.5660
# Episode: 338 Total reward: 16.0 Training loss: 40.0400 Explore P: 0.5651
# Episode: 339 Total reward: 12.0 Training loss: 42.7039 Explore P: 0.5645
# Episode: 340 Total reward: 23.0 Training loss: 1.9347 Explore P: 0.5632
# Episode: 341 Total reward: 31.0 Training loss: 17.6528 Explore P: 0.5615
# Episode: 342 Total reward: 11.0 Training loss: 25.1486 Explore P: 0.5609
# Episode: 343 Total reward: 19.0 Training loss: 1.8787 Explore P: 0.5598
# Episode: 344 Total reward: 11.0 Training loss: 1.7642 Explore P: 0.5592
# Episode: 345 Total reward: 10.0 Training loss: 104.3849 Explore P: 0.5587
# Episode: 346 Total reward: 25.0 Training loss: 32.6551 Explore P: 0.5573
# Episode: 347 Total reward: 15.0 Training loss: 16.7533 Explore P: 0.5565
# Episode: 348 Total reward: 13.0 Training loss: 76.4637 Explore P: 0.5558
# Episode: 349 Total reward: 10.0 Training loss: 56.3092 Explore P: 0.5552
# Episode: 350 Total reward: 22.0 Training loss: 72.9948 Explore P: 0.5540
# Episode: 351 Total reward: 34.0 Training loss: 34.6278 Explore P: 0.5522
# Episode: 352 Total reward: 10.0 Training loss: 1.0531 Explore P: 0.5516
# Episode: 353 Total reward: 7.0 Training loss: 1.0240 Explore P: 0.5513
# Episode: 354 Total reward: 8.0 Training loss: 35.3551 Explore P: 0.5508
# Episode: 355 Total reward: 12.0 Training loss: 31.3760 Explore P: 0.5502
# Episode: 356 Total reward: 16.0 Training loss: 0.7999 Explore P: 0.5493
# Episode: 357 Total reward: 16.0 Training loss: 1.2919 Explore P: 0.5485
# Episode: 358 Total reward: 10.0 Training loss: 1.3556 Explore P: 0.5479
# Episode: 359 Total reward: 11.0 Training loss: 62.3749 Explore P: 0.5473
# Episode: 360 Total reward: 21.0 Training loss: 29.4711 Explore P: 0.5462
# Episode: 361 Total reward: 15.0 Training loss: 51.9935 Explore P: 0.5454
# Episode: 362 Total reward: 24.0 Training loss: 0.8793 Explore P: 0.5441
# Episode: 363 Total reward: 11.0 Training loss: 1.0507 Explore P: 0.5435
# Episode: 364 Total reward: 14.0 Training loss: 45.6587 Explore P: 0.5428
# Episode: 365 Total reward: 12.0 Training loss: 16.9353 Explore P: 0.5421
# Episode: 366 Total reward: 12.0 Training loss: 17.9708 Explore P: 0.5415
# Episode: 367 Total reward: 12.0 Training loss: 78.8387 Explore P: 0.5409
# Episode: 368 Total reward: 12.0 Training loss: 1.0068 Explore P: 0.5402
# Episode: 369 Total reward: 13.0 Training loss: 1.0017 Explore P: 0.5395
# Episode: 370 Total reward: 9.0 Training loss: 38.7998 Explore P: 0.5391
# Episode: 371 Total reward: 9.0 Training loss: 24.9862 Explore P: 0.5386
# Episode: 372 Total reward: 14.0 Training loss: 1.3054 Explore P: 0.5378
# Episode: 373 Total reward: 12.0 Training loss: 0.6447 Explore P: 0.5372
# Episode: 374 Total reward: 14.0 Training loss: 0.9916 Explore P: 0.5365
# Episode: 375 Total reward: 10.0 Training loss: 16.2685 Explore P: 0.5359
# Episode: 376 Total reward: 9.0 Training loss: 24.9013 Explore P: 0.5355
# Episode: 377 Total reward: 10.0 Training loss: 47.3566 Explore P: 0.5350
# Episode: 378 Total reward: 13.0 Training loss: 18.2883 Explore P: 0.5343
# Episode: 379 Total reward: 51.0 Training loss: 1.0961 Explore P: 0.5316
# Episode: 380 Total reward: 76.0 Training loss: 35.3271 Explore P: 0.5277
# Episode: 381 Total reward: 16.0 Training loss: 70.9007 Explore P: 0.5268
# Episode: 382 Total reward: 20.0 Training loss: 0.5633 Explore P: 0.5258
# Episode: 383 Total reward: 108.0 Training loss: 17.9930 Explore P: 0.5203
# Episode: 384 Total reward: 13.0 Training loss: 16.9434 Explore P: 0.5196
# Episode: 385 Total reward: 65.0 Training loss: 0.7724 Explore P: 0.5163
# Episode: 386 Total reward: 98.0 Training loss: 0.8695 Explore P: 0.5114
# Episode: 387 Total reward: 50.0 Training loss: 43.0038 Explore P: 0.5088
# Episode: 388 Total reward: 14.0 Training loss: 14.3801 Explore P: 0.5082
# Episode: 389 Total reward: 30.0 Training loss: 25.1250 Explore P: 0.5067
# Episode: 390 Total reward: 22.0 Training loss: 0.7307 Explore P: 0.5056
# Episode: 391 Total reward: 36.0 Training loss: 1.0069 Explore P: 0.5038
# Episode: 392 Total reward: 17.0 Training loss: 40.0084 Explore P: 0.5029
# Episode: 393 Total reward: 57.0 Training loss: 1.1947 Explore P: 0.5001
# Episode: 394 Total reward: 50.0 Training loss: 10.8768 Explore P: 0.4977
# Episode: 395 Total reward: 58.0 Training loss: 0.7167 Explore P: 0.4949
# Episode: 396 Total reward: 39.0 Training loss: 13.8439 Explore P: 0.4930
# Episode: 397 Total reward: 106.0 Training loss: 12.3573 Explore P: 0.4879
# Episode: 398 Total reward: 38.0 Training loss: 15.8551 Explore P: 0.4861
# Episode: 399 Total reward: 112.0 Training loss: 12.0141 Explore P: 0.4808
# Episode: 400 Total reward: 108.0 Training loss: 1.1874 Explore P: 0.4757
# Episode: 401 Total reward: 88.0 Training loss: 12.5271 Explore P: 0.4716
# Episode: 402 Total reward: 50.0 Training loss: 1.4161 Explore P: 0.4693
# Episode: 403 Total reward: 27.0 Training loss: 15.1781 Explore P: 0.4681
# Episode: 404 Total reward: 97.0 Training loss: 0.8745 Explore P: 0.4637
# Episode: 405 Total reward: 102.0 Training loss: 1.0225 Explore P: 0.4591
# Episode: 406 Total reward: 60.0 Training loss: 13.4786 Explore P: 0.4564
# Episode: 407 Total reward: 81.0 Training loss: 1.3541 Explore P: 0.4528
# Episode: 408 Total reward: 78.0 Training loss: 34.9784 Explore P: 0.4494
# Episode: 409 Total reward: 31.0 Training loss: 1.2743 Explore P: 0.4480
# Episode: 410 Total reward: 76.0 Training loss: 1.2018 Explore P: 0.4447
# Episode: 411 Total reward: 112.0 Training loss: 0.7670 Explore P: 0.4398
# Episode: 412 Total reward: 54.0 Training loss: 16.9623 Explore P: 0.4375
# Episode: 413 Total reward: 78.0 Training loss: 1.9267 Explore P: 0.4342
# Episode: 414 Total reward: 25.0 Training loss: 14.8737 Explore P: 0.4331
# Episode: 415 Total reward: 58.0 Training loss: 13.2250 Explore P: 0.4307
# Episode: 416 Total reward: 73.0 Training loss: 1.1747 Explore P: 0.4276
# Episode: 417 Total reward: 42.0 Training loss: 10.3525 Explore P: 0.4259
# Episode: 418 Total reward: 103.0 Training loss: 1.0778 Explore P: 0.4216
# Episode: 419 Total reward: 112.0 Training loss: 33.1558 Explore P: 0.4170
# Episode: 420 Total reward: 85.0 Training loss: 15.5235 Explore P: 0.4136
# Episode: 421 Total reward: 73.0 Training loss: 1.2451 Explore P: 0.4107
# Episode: 422 Total reward: 65.0 Training loss: 28.4374 Explore P: 0.4081
# Episode: 423 Total reward: 86.0 Training loss: 15.2476 Explore P: 0.4047
# Episode: 424 Total reward: 86.0 Training loss: 18.8881 Explore P: 0.4013
# Episode: 425 Total reward: 49.0 Training loss: 33.1894 Explore P: 0.3994
# Episode: 426 Total reward: 49.0 Training loss: 35.5896 Explore P: 0.3975
# Episode: 427 Total reward: 43.0 Training loss: 23.2921 Explore P: 0.3958
# Episode: 428 Total reward: 33.0 Training loss: 43.0312 Explore P: 0.3945
# Episode: 429 Total reward: 48.0 Training loss: 37.7203 Explore P: 0.3927
# Episode: 430 Total reward: 62.0 Training loss: 39.7490 Explore P: 0.3903
# Episode: 431 Total reward: 88.0 Training loss: 1.8381 Explore P: 0.3870
# Episode: 432 Total reward: 27.0 Training loss: 1.1937 Explore P: 0.3860
# Episode: 433 Total reward: 133.0 Training loss: 32.3906 Explore P: 0.3810
# Episode: 434 Total reward: 57.0 Training loss: 16.4042 Explore P: 0.3789
# Episode: 435 Total reward: 76.0 Training loss: 1.7581 Explore P: 0.3761
# Episode: 436 Total reward: 57.0 Training loss: 1.0707 Explore P: 0.3740
# Episode: 437 Total reward: 75.0 Training loss: 25.6262 Explore P: 0.3713
# Episode: 438 Total reward: 50.0 Training loss: 20.9490 Explore P: 0.3695
# Episode: 439 Total reward: 48.0 Training loss: 32.1081 Explore P: 0.3678
# Episode: 440 Total reward: 49.0 Training loss: 1.8103 Explore P: 0.3660
# Episode: 441 Total reward: 137.0 Training loss: 1.5771 Explore P: 0.3612
# Episode: 442 Total reward: 55.0 Training loss: 1.6093 Explore P: 0.3593
# Episode: 443 Total reward: 42.0 Training loss: 15.4736 Explore P: 0.3578
# Episode: 444 Total reward: 60.0 Training loss: 1.6638 Explore P: 0.3557
# Episode: 445 Total reward: 56.0 Training loss: 1.3391 Explore P: 0.3538
# Episode: 446 Total reward: 18.0 Training loss: 46.0570 Explore P: 0.3532
# Episode: 447 Total reward: 101.0 Training loss: 1.3012 Explore P: 0.3497
# Episode: 448 Total reward: 49.0 Training loss: 50.7267 Explore P: 0.3481
# Episode: 449 Total reward: 48.0 Training loss: 2.1538 Explore P: 0.3464
# Episode: 450 Total reward: 24.0 Training loss: 1.8092 Explore P: 0.3456
# Episode: 451 Total reward: 23.0 Training loss: 45.4994 Explore P: 0.3449
# Episode: 452 Total reward: 65.0 Training loss: 1.3738 Explore P: 0.3427
# Episode: 453 Total reward: 68.0 Training loss: 53.5276 Explore P: 0.3404
# Episode: 454 Total reward: 66.0 Training loss: 1.7965 Explore P: 0.3383
# Episode: 455 Total reward: 99.0 Training loss: 2.4168 Explore P: 0.3350
# Episode: 456 Total reward: 67.0 Training loss: 2.0679 Explore P: 0.3329
# Episode: 457 Total reward: 52.0 Training loss: 1.4981 Explore P: 0.3312
# Episode: 458 Total reward: 47.0 Training loss: 1.3825 Explore P: 0.3297
# Episode: 459 Total reward: 45.0 Training loss: 1.5583 Explore P: 0.3282
# Episode: 460 Total reward: 14.0 Training loss: 52.7166 Explore P: 0.3278
# Episode: 461 Total reward: 40.0 Training loss: 59.5450 Explore P: 0.3265
# Episode: 462 Total reward: 28.0 Training loss: 81.4752 Explore P: 0.3256
# Episode: 463 Total reward: 59.0 Training loss: 56.7850 Explore P: 0.3238
# Episode: 464 Total reward: 85.0 Training loss: 35.3923 Explore P: 0.3211
# Episode: 465 Total reward: 109.0 Training loss: 76.8149 Explore P: 0.3178
# Episode: 466 Total reward: 126.0 Training loss: 2.1983 Explore P: 0.3139
# Episode: 467 Total reward: 60.0 Training loss: 2.9343 Explore P: 0.3121
# Episode: 468 Total reward: 93.0 Training loss: 1.3402 Explore P: 0.3093
# Episode: 469 Total reward: 98.0 Training loss: 59.1224 Explore P: 0.3064
# Episode: 470 Total reward: 38.0 Training loss: 74.4320 Explore P: 0.3052
# Episode: 471 Total reward: 149.0 Training loss: 1.1972 Explore P: 0.3009
# Episode: 472 Total reward: 174.0 Training loss: 57.4168 Explore P: 0.2959
# Episode: 473 Total reward: 75.0 Training loss: 16.9733 Explore P: 0.2937
# Episode: 474 Total reward: 51.0 Training loss: 1.3943 Explore P: 0.2923
# Episode: 475 Total reward: 51.0 Training loss: 1.9690 Explore P: 0.2908
# Episode: 476 Total reward: 98.0 Training loss: 68.4876 Explore P: 0.2881
# Episode: 477 Total reward: 162.0 Training loss: 1.3619 Explore P: 0.2836
# Episode: 478 Total reward: 147.0 Training loss: 1.9090 Explore P: 0.2796
# Episode: 479 Total reward: 59.0 Training loss: 40.7132 Explore P: 0.2781
# Episode: 480 Total reward: 46.0 Training loss: 96.9360 Explore P: 0.2768
# Episode: 481 Total reward: 81.0 Training loss: 2.5922 Explore P: 0.2747
# Episode: 482 Total reward: 146.0 Training loss: 1.7398 Explore P: 0.2708
# Episode: 483 Total reward: 79.0 Training loss: 1.9503 Explore P: 0.2688
# Episode: 484 Total reward: 93.0 Training loss: 2.5378 Explore P: 0.2664
# Episode: 485 Total reward: 18.0 Training loss: 2.0289 Explore P: 0.2659
# Episode: 486 Total reward: 81.0 Training loss: 1.6824 Explore P: 0.2639
# Episode: 487 Total reward: 121.0 Training loss: 133.1911 Explore P: 0.2608
# Episode: 488 Total reward: 36.0 Training loss: 1.8454 Explore P: 0.2599
# Episode: 489 Total reward: 26.0 Training loss: 1.7348 Explore P: 0.2593
# Episode: 490 Total reward: 79.0 Training loss: 15.8814 Explore P: 0.2573
# Episode: 491 Total reward: 52.0 Training loss: 0.9582 Explore P: 0.2560
# Episode: 492 Total reward: 49.0 Training loss: 2.0291 Explore P: 0.2548
# Episode: 493 Total reward: 52.0 Training loss: 2.5159 Explore P: 0.2535
# Episode: 494 Total reward: 122.0 Training loss: 77.7079 Explore P: 0.2506
# Episode: 495 Total reward: 42.0 Training loss: 2.8979 Explore P: 0.2496
# Episode: 496 Total reward: 51.0 Training loss: 103.7606 Explore P: 0.2484
# Episode: 497 Total reward: 25.0 Training loss: 108.4597 Explore P: 0.2478
# Episode: 498 Total reward: 31.0 Training loss: 36.7159 Explore P: 0.2470
# Episode: 499 Total reward: 22.0 Training loss: 55.6042 Explore P: 0.2465
# Episode: 500 Total reward: 33.0 Training loss: 2.1856 Explore P: 0.2457
# Episode: 501 Total reward: 34.0 Training loss: 115.5493 Explore P: 0.2449
# Episode: 502 Total reward: 42.0 Training loss: 1.2537 Explore P: 0.2439
# Episode: 503 Total reward: 38.0 Training loss: 75.1539 Explore P: 0.2431
# Episode: 504 Total reward: 27.0 Training loss: 41.4018 Explore P: 0.2424
# Episode: 505 Total reward: 22.0 Training loss: 12.5471 Explore P: 0.2419
# Episode: 506 Total reward: 25.0 Training loss: 2.7426 Explore P: 0.2413
# Episode: 507 Total reward: 22.0 Training loss: 24.4062 Explore P: 0.2408
# Episode: 508 Total reward: 20.0 Training loss: 74.3189 Explore P: 0.2404
# Episode: 509 Total reward: 28.0 Training loss: 2.1957 Explore P: 0.2397
# Episode: 510 Total reward: 30.0 Training loss: 5.3903 Explore P: 0.2390
# Episode: 511 Total reward: 28.0 Training loss: 2.6493 Explore P: 0.2384
# Episode: 512 Total reward: 33.0 Training loss: 257.7379 Explore P: 0.2376
# Episode: 513 Total reward: 28.0 Training loss: 2.3621 Explore P: 0.2370
# Episode: 514 Total reward: 30.0 Training loss: 125.2012 Explore P: 0.2363
# Episode: 515 Total reward: 21.0 Training loss: 6.0645 Explore P: 0.2359
# Episode: 516 Total reward: 24.0 Training loss: 1.7140 Explore P: 0.2353
# Episode: 517 Total reward: 25.0 Training loss: 113.7582 Explore P: 0.2348
# Episode: 518 Total reward: 32.0 Training loss: 1.8458 Explore P: 0.2340
# Episode: 519 Total reward: 23.0 Training loss: 3.9085 Explore P: 0.2335
# Episode: 520 Total reward: 38.0 Training loss: 3.7752 Explore P: 0.2327
# Episode: 521 Total reward: 42.0 Training loss: 47.7598 Explore P: 0.2317
# Episode: 522 Total reward: 34.0 Training loss: 1.3908 Explore P: 0.2310
# Episode: 523 Total reward: 67.0 Training loss: 52.3255 Explore P: 0.2295
# Episode: 524 Total reward: 69.0 Training loss: 65.0005 Explore P: 0.2280
# Episode: 525 Total reward: 25.0 Training loss: 2.1334 Explore P: 0.2275
# Episode: 526 Total reward: 45.0 Training loss: 1.1417 Explore P: 0.2265
# Episode: 527 Total reward: 60.0 Training loss: 257.7955 Explore P: 0.2252
# Episode: 528 Total reward: 73.0 Training loss: 107.3899 Explore P: 0.2236
# Episode: 529 Total reward: 30.0 Training loss: 1.3043 Explore P: 0.2230
# Episode: 530 Total reward: 43.0 Training loss: 1.1473 Explore P: 0.2221
# Episode: 531 Total reward: 95.0 Training loss: 1.7923 Explore P: 0.2201
# Episode: 532 Total reward: 37.0 Training loss: 116.9125 Explore P: 0.2193
# Episode: 533 Total reward: 45.0 Training loss: 51.6290 Explore P: 0.2183
# Episode: 534 Total reward: 63.0 Training loss: 1.6227 Explore P: 0.2170
# Episode: 535 Total reward: 49.0 Training loss: 30.3040 Explore P: 0.2160
# Episode: 536 Total reward: 77.0 Training loss: 1.5739 Explore P: 0.2144
# Episode: 537 Total reward: 67.0 Training loss: 2.2570 Explore P: 0.2131
# Episode: 538 Total reward: 199.0 Training loss: 2.6158 Explore P: 0.2091
# Episode: 539 Total reward: 146.0 Training loss: 0.8250 Explore P: 0.2062
# Episode: 540 Total reward: 199.0 Training loss: 1.5687 Explore P: 0.2023
# Episode: 541 Total reward: 189.0 Training loss: 1.2360 Explore P: 0.1987
# Episode: 542 Total reward: 152.0 Training loss: 68.4029 Explore P: 0.1959
# Episode: 543 Total reward: 199.0 Training loss: 1.8049 Explore P: 0.1922
# Episode: 544 Total reward: 199.0 Training loss: 95.1164 Explore P: 0.1886
# Episode: 545 Total reward: 199.0 Training loss: 1.2360 Explore P: 0.1851
# Episode: 546 Total reward: 199.0 Training loss: 104.7594 Explore P: 0.1817
# Episode: 547 Total reward: 199.0 Training loss: 2.1027 Explore P: 0.1783
# Episode: 548 Total reward: 199.0 Training loss: 90.2557 Explore P: 0.1750
# Episode: 549 Total reward: 159.0 Training loss: 1.3533 Explore P: 0.1724
# Episode: 550 Total reward: 199.0 Training loss: 1.7398 Explore P: 0.1692
# Episode: 551 Total reward: 199.0 Training loss: 0.9854 Explore P: 0.1660
# Episode: 552 Total reward: 199.0 Training loss: 1.5859 Explore P: 0.1629
# Episode: 553 Total reward: 199.0 Training loss: 1.3609 Explore P: 0.1599
# Episode: 554 Total reward: 199.0 Training loss: 118.8703 Explore P: 0.1570
# Episode: 555 Total reward: 199.0 Training loss: 1.4071 Explore P: 0.1541
# Episode: 556 Total reward: 199.0 Training loss: 1.2896 Explore P: 0.1512
# Episode: 557 Total reward: 199.0 Training loss: 128.6667 Explore P: 0.1485
# Episode: 558 Total reward: 199.0 Training loss: 0.9811 Explore P: 0.1457
# Episode: 559 Total reward: 199.0 Training loss: 0.9054 Explore P: 0.1431
# Episode: 560 Total reward: 199.0 Training loss: 203.8293 Explore P: 0.1404
# Episode: 561 Total reward: 179.0 Training loss: 0.7547 Explore P: 0.1381
# Episode: 562 Total reward: 141.0 Training loss: 0.9100 Explore P: 0.1363
# Episode: 563 Total reward: 192.0 Training loss: 0.8624 Explore P: 0.1339
# Episode: 564 Total reward: 187.0 Training loss: 1.4043 Explore P: 0.1316
# Episode: 565 Total reward: 186.0 Training loss: 1.1053 Explore P: 0.1294
# Episode: 566 Total reward: 163.0 Training loss: 1.1174 Explore P: 0.1275
# Episode: 567 Total reward: 150.0 Training loss: 0.5058 Explore P: 0.1257
# Episode: 568 Total reward: 135.0 Training loss: 1.7326 Explore P: 0.1242
# Episode: 569 Total reward: 152.0 Training loss: 1.3369 Explore P: 0.1224
# Episode: 570 Total reward: 145.0 Training loss: 1.6198 Explore P: 0.1208
# Episode: 571 Total reward: 178.0 Training loss: 127.9199 Explore P: 0.1189
# Episode: 572 Total reward: 160.0 Training loss: 1.7653 Explore P: 0.1171
# Episode: 573 Total reward: 159.0 Training loss: 0.8854 Explore P: 0.1154
# Episode: 574 Total reward: 137.0 Training loss: 1.4882 Explore P: 0.1140
# Episode: 575 Total reward: 135.0 Training loss: 155.8313 Explore P: 0.1126
# Episode: 576 Total reward: 137.0 Training loss: 0.7018 Explore P: 0.1112
# Episode: 577 Total reward: 158.0 Training loss: 0.4385 Explore P: 0.1096
# Episode: 578 Total reward: 127.0 Training loss: 1.6914 Explore P: 0.1084
# Episode: 579 Total reward: 121.0 Training loss: 1.2562 Explore P: 0.1072
# Episode: 580 Total reward: 119.0 Training loss: 1.4896 Explore P: 0.1060
# Episode: 581 Total reward: 132.0 Training loss: 0.8721 Explore P: 0.1048
# Episode: 582 Total reward: 147.0 Training loss: 135.1636 Explore P: 0.1034
# Episode: 583 Total reward: 136.0 Training loss: 0.8168 Explore P: 0.1021
# Episode: 584 Total reward: 126.0 Training loss: 0.8619 Explore P: 0.1010
# Episode: 585 Total reward: 121.0 Training loss: 1.4692 Explore P: 0.0999
# Episode: 586 Total reward: 105.0 Training loss: 181.0183 Explore P: 0.0990
# Episode: 587 Total reward: 145.0 Training loss: 1.6624 Explore P: 0.0977
# Episode: 588 Total reward: 126.0 Training loss: 0.7120 Explore P: 0.0966
# Episode: 589 Total reward: 108.0 Training loss: 1.3868 Explore P: 0.0956
# Episode: 590 Total reward: 107.0 Training loss: 1.9556 Explore P: 0.0947
# Episode: 591 Total reward: 18.0 Training loss: 1.4142 Explore P: 0.0946
# Episode: 592 Total reward: 106.0 Training loss: 1.1637 Explore P: 0.0937
# Episode: 593 Total reward: 35.0 Training loss: 333.5367 Explore P: 0.0934
# Episode: 594 Total reward: 33.0 Training loss: 2.2201 Explore P: 0.0931
# Episode: 595 Total reward: 116.0 Training loss: 1.2101 Explore P: 0.0922
# Episode: 596 Total reward: 27.0 Training loss: 1.2886 Explore P: 0.0919
# Episode: 597 Total reward: 26.0 Training loss: 1.7631 Explore P: 0.0917
# Episode: 598 Total reward: 20.0 Training loss: 0.6390 Explore P: 0.0916
# Episode: 599 Total reward: 108.0 Training loss: 1.1044 Explore P: 0.0907
# Episode: 600 Total reward: 30.0 Training loss: 1.0482 Explore P: 0.0904
# Episode: 601 Total reward: 24.0 Training loss: 1.7818 Explore P: 0.0903
# Episode: 602 Total reward: 21.0 Training loss: 2.3629 Explore P: 0.0901
# Episode: 603 Total reward: 20.0 Training loss: 1.9776 Explore P: 0.0899
# Episode: 604 Total reward: 22.0 Training loss: 1.2909 Explore P: 0.0898
# Episode: 605 Total reward: 17.0 Training loss: 108.8021 Explore P: 0.0896
# Episode: 606 Total reward: 31.0 Training loss: 0.7178 Explore P: 0.0894
# Episode: 607 Total reward: 102.0 Training loss: 2.6779 Explore P: 0.0886
# Episode: 608 Total reward: 25.0 Training loss: 2.4042 Explore P: 0.0884
# Episode: 609 Total reward: 20.0 Training loss: 0.9108 Explore P: 0.0882
# Episode: 610 Total reward: 30.0 Training loss: 0.6532 Explore P: 0.0880
# Episode: 611 Total reward: 19.0 Training loss: 0.9871 Explore P: 0.0878
# Episode: 612 Total reward: 32.0 Training loss: 0.4984 Explore P: 0.0876
# Episode: 613 Total reward: 19.0 Training loss: 1.1650 Explore P: 0.0874
# Episode: 614 Total reward: 31.0 Training loss: 0.7644 Explore P: 0.0872
# Episode: 615 Total reward: 93.0 Training loss: 0.4927 Explore P: 0.0865
# Episode: 616 Total reward: 33.0 Training loss: 0.7406 Explore P: 0.0862
# Episode: 617 Total reward: 26.0 Training loss: 0.7850 Explore P: 0.0860
# Episode: 618 Total reward: 107.0 Training loss: 0.7083 Explore P: 0.0852
# Episode: 619 Total reward: 130.0 Training loss: 0.7724 Explore P: 0.0842
# Episode: 620 Total reward: 139.0 Training loss: 847.3906 Explore P: 0.0832
# Episode: 621 Total reward: 104.0 Training loss: 1.0793 Explore P: 0.0825
# Episode: 622 Total reward: 125.0 Training loss: 0.7389 Explore P: 0.0816
# Episode: 623 Total reward: 181.0 Training loss: 131.9855 Explore P: 0.0803
# Episode: 624 Total reward: 199.0 Training loss: 0.5163 Explore P: 0.0789
# Episode: 625 Total reward: 178.0 Training loss: 0.6042 Explore P: 0.0777
# Episode: 626 Total reward: 199.0 Training loss: 0.3966 Explore P: 0.0763
# Episode: 627 Total reward: 199.0 Training loss: 24.7791 Explore P: 0.0750
# Episode: 628 Total reward: 199.0 Training loss: 0.6462 Explore P: 0.0738
# Episode: 629 Total reward: 199.0 Training loss: 0.2697 Explore P: 0.0725
# Episode: 630 Total reward: 199.0 Training loss: 0.5513 Explore P: 0.0713
# Episode: 631 Total reward: 199.0 Training loss: 0.2808 Explore P: 0.0701
# Episode: 632 Total reward: 199.0 Training loss: 0.2921 Explore P: 0.0689
# Episode: 633 Total reward: 199.0 Training loss: 0.2734 Explore P: 0.0677
# Episode: 634 Total reward: 199.0 Training loss: 0.8069 Explore P: 0.0666
# Episode: 635 Total reward: 199.0 Training loss: 229.3620 Explore P: 0.0655
# Episode: 636 Total reward: 175.0 Training loss: 1.2089 Explore P: 0.0645
# Episode: 637 Total reward: 199.0 Training loss: 60.7077 Explore P: 0.0634
# Episode: 638 Total reward: 199.0 Training loss: 0.7794 Explore P: 0.0624
# Episode: 639 Total reward: 199.0 Training loss: 0.3000 Explore P: 0.0613
# Episode: 640 Total reward: 199.0 Training loss: 0.4493 Explore P: 0.0603
# Episode: 641 Total reward: 199.0 Training loss: 0.2102 Explore P: 0.0593
# Episode: 642 Total reward: 199.0 Training loss: 351.4139 Explore P: 0.0584
# Episode: 643 Total reward: 199.0 Training loss: 0.3411 Explore P: 0.0574
# Episode: 644 Total reward: 199.0 Training loss: 0.3165 Explore P: 0.0565
# Episode: 645 Total reward: 199.0 Training loss: 0.2954 Explore P: 0.0556
# Episode: 646 Total reward: 199.0 Training loss: 12.0057 Explore P: 0.0547
# Episode: 647 Total reward: 199.0 Training loss: 0.2534 Explore P: 0.0538
# Episode: 648 Total reward: 199.0 Training loss: 0.3667 Explore P: 0.0529
# Episode: 649 Total reward: 199.0 Training loss: 0.3383 Explore P: 0.0521
# Episode: 650 Total reward: 199.0 Training loss: 0.3614 Explore P: 0.0513
# Episode: 651 Total reward: 199.0 Training loss: 0.3135 Explore P: 0.0504
# Episode: 652 Total reward: 199.0 Training loss: 0.1586 Explore P: 0.0496
# Episode: 653 Total reward: 199.0 Training loss: 0.3181 Explore P: 0.0489
# Episode: 654 Total reward: 199.0 Training loss: 0.3304 Explore P: 0.0481
# Episode: 655 Total reward: 199.0 Training loss: 267.7386 Explore P: 0.0473
# Episode: 656 Total reward: 199.0 Training loss: 0.2966 Explore P: 0.0466
# Episode: 657 Total reward: 199.0 Training loss: 0.2335 Explore P: 0.0459
# Episode: 658 Total reward: 199.0 Training loss: 178.5898 Explore P: 0.0452
# Episode: 659 Total reward: 199.0 Training loss: 0.3422 Explore P: 0.0445
# Episode: 660 Total reward: 199.0 Training loss: 0.1794 Explore P: 0.0438
# ...
# Episode: 781 Total reward: 199.0 Training loss: 0.2948 Explore P: 0.0132
# Episode: 782 Total reward: 199.0 Training loss: 0.3494 Explore P: 0.0132
# Episode: 783 Total reward: 199.0 Training loss: 0.3011 Explore P: 0.0131
# Episode: 784 Total reward: 199.0 Training loss: 0.3532 Explore P: 0.0130
# Episode: 785 Total reward: 199.0 Training loss: 0.4327 Explore P: 0.0130
# Episode: 786 Total reward: 199.0 Training loss: 0.2597 Explore P: 0.0129
# Episode: 787 Total reward: 199.0 Training loss: 0.4332 Explore P: 0.0129
# Episode: 788 Total reward: 199.0 Training loss: 0.4131 Explore P: 0.0128
# Episode: 789 Total reward: 199.0 Training loss: 0.4868 Explore P: 0.0127
# Episode: 790 Total reward: 199.0 Training loss: 194.4520 Explore P: 0.0127
# Episode: 791 Total reward: 199.0 Training loss: 0.4175 Explore P: 0.0126
# Episode: 792 Total reward: 199.0 Training loss: 0.4733 Explore P: 0.0126
# Episode: 793 Total reward: 199.0 Training loss: 0.5999 Explore P: 0.0125
# Episode: 794 Total reward: 188.0 Training loss: 0.4730 Explore P: 0.0125
# Episode: 795 Total reward: 199.0 Training loss: 0.2670 Explore P: 0.0124
# Episode: 796 Total reward: 199.0 Training loss: 0.3247 Explore P: 0.0124
# Episode: 797 Total reward: 199.0 Training loss: 0.2771 Explore P: 0.0123
# Episode: 798 Total reward: 199.0 Training loss: 0.3479 Explore P: 0.0123
# Episode: 799 Total reward: 193.0 Training loss: 333.0209 Explore P: 0.0123
# Episode: 800 Total reward: 184.0 Training loss: 0.3428 Explore P: 0.0122
# Episode: 801 Total reward: 195.0 Training loss: 0.6158 Explore P: 0.0122
# Episode: 802 Total reward: 168.0 Training loss: 0.5204 Explore P: 0.0121
# Episode: 803 Total reward: 155.0 Training loss: 0.3998 Explore P: 0.0121
# Episode: 804 Total reward: 124.0 Training loss: 0.3019 Explore P: 0.0121
# Episode: 805 Total reward: 157.0 Training loss: 448.6315 Explore P: 0.0120
# Episode: 806 Total reward: 140.0 Training loss: 0.8843 Explore P: 0.0120
# Episode: 807 Total reward: 21.0 Training loss: 0.8094 Explore P: 0.0120
# Episode: 808 Total reward: 123.0 Training loss: 1.3195 Explore P: 0.0120
# Episode: 809 Total reward: 15.0 Training loss: 1.0454 Explore P: 0.0120
# Episode: 810 Total reward: 12.0 Training loss: 0.9130 Explore P: 0.0120
# Episode: 811 Total reward: 15.0 Training loss: 1.3698 Explore P: 0.0120
# Episode: 812 Total reward: 14.0 Training loss: 1.8110 Explore P: 0.0120
# Episode: 813 Total reward: 12.0 Training loss: 2.0684 Explore P: 0.0120
# Episode: 814 Total reward: 14.0 Training loss: 1.1194 Explore P: 0.0120
# Episode: 815 Total reward: 12.0 Training loss: 1.0484 Explore P: 0.0120
# Episode: 816 Total reward: 27.0 Training loss: 441.3491 Explore P: 0.0120
# Episode: 817 Total reward: 13.0 Training loss: 0.5213 Explore P: 0.0120
# Episode: 818 Total reward: 18.0 Training loss: 0.8366 Explore P: 0.0120
# Episode: 819 Total reward: 18.0 Training loss: 0.7964 Explore P: 0.0119
# Episode: 820 Total reward: 15.0 Training loss: 1.0885 Explore P: 0.0119
# Episode: 821 Total reward: 19.0 Training loss: 468.7130 Explore P: 0.0119
# Episode: 822 Total reward: 18.0 Training loss: 0.9987 Explore P: 0.0119
# Episode: 823 Total reward: 23.0 Training loss: 0.7146 Explore P: 0.0119
# Episode: 824 Total reward: 14.0 Training loss: 438.2842 Explore P: 0.0119
# Episode: 825 Total reward: 20.0 Training loss: 0.6840 Explore P: 0.0119
# Episode: 826 Total reward: 33.0 Training loss: 0.5909 Explore P: 0.0119
# Episode: 827 Total reward: 123.0 Training loss: 446.6839 Explore P: 0.0119
# Episode: 828 Total reward: 148.0 Training loss: 0.7565 Explore P: 0.0119
# Episode: 829 Total reward: 182.0 Training loss: 0.6733 Explore P: 0.0118
# Episode: 830 Total reward: 156.0 Training loss: 345.6290 Explore P: 0.0118
# Episode: 831 Total reward: 178.0 Training loss: 0.3846 Explore P: 0.0118
# Episode: 832 Total reward: 151.0 Training loss: 241.9846 Explore P: 0.0117
# Episode: 833 Total reward: 199.0 Training loss: 355.2611 Explore P: 0.0117
# Episode: 834 Total reward: 150.0 Training loss: 0.7374 Explore P: 0.0117
# Episode: 835 Total reward: 170.0 Training loss: 177.2054 Explore P: 0.0117
# Episode: 836 Total reward: 199.0 Training loss: 300.1219 Explore P: 0.0116
# Episode: 837 Total reward: 199.0 Training loss: 0.3329 Explore P: 0.0116
# Episode: 838 Total reward: 199.0 Training loss: 0.1822 Explore P: 0.0116
# Episode: 839 Total reward: 182.0 Training loss: 0.2426 Explore P: 0.0115
# Episode: 840 Total reward: 199.0 Training loss: 0.3714 Explore P: 0.0115
# Episode: 841 Total reward: 199.0 Training loss: 0.4492 Explore P: 0.0115
# Episode: 842 Total reward: 199.0 Training loss: 0.3624 Explore P: 0.0114
# Episode: 843 Total reward: 199.0 Training loss: 0.2064 Explore P: 0.0114
# Episode: 844 Total reward: 199.0 Training loss: 0.2981 Explore P: 0.0114
# Episode: 845 Total reward: 199.0 Training loss: 0.3300 Explore P: 0.0114
# Episode: 846 Total reward: 199.0 Training loss: 0.3012 Explore P: 0.0113
# Episode: 847 Total reward: 199.0 Training loss: 0.1164 Explore P: 0.0113
# Episode: 848 Total reward: 199.0 Training loss: 0.3247 Explore P: 0.0113
# Episode: 849 Total reward: 199.0 Training loss: 0.3239 Explore P: 0.0113
# Episode: 850 Total reward: 199.0 Training loss: 0.4602 Explore P: 0.0112
# Episode: 851 Total reward: 199.0 Training loss: 0.3416 Explore P: 0.0112
# Episode: 852 Total reward: 199.0 Training loss: 0.5325 Explore P: 0.0112
# Episode: 853 Total reward: 199.0 Training loss: 0.3166 Explore P: 0.0112
# Episode: 854 Total reward: 199.0 Training loss: 0.5074 Explore P: 0.0111
# Episode: 855 Total reward: 199.0 Training loss: 0.5450 Explore P: 0.0111
# Episode: 856 Total reward: 199.0 Training loss: 0.5051 Explore P: 0.0111
# Episode: 857 Total reward: 199.0 Training loss: 0.6989 Explore P: 0.0111
# Episode: 858 Total reward: 199.0 Training loss: 0.5219 Explore P: 0.0111
# Episode: 859 Total reward: 199.0 Training loss: 0.2756 Explore P: 0.0110
# Episode: 860 Total reward: 199.0 Training loss: 0.3807 Explore P: 0.0110
# Episode: 861 Total reward: 199.0 Training loss: 0.2033 Explore P: 0.0110
# Episode: 862 Total reward: 199.0 Training loss: 0.5098 Explore P: 0.0110
# Episode: 863 Total reward: 199.0 Training loss: 0.3746 Explore P: 0.0110
# Episode: 864 Total reward: 199.0 Training loss: 0.4204 Explore P: 0.0109
# Episode: 865 Total reward: 199.0 Training loss: 0.3671 Explore P: 0.0109
# Episode: 866 Total reward: 199.0 Training loss: 0.3694 Explore P: 0.0109
# Episode: 867 Total reward: 199.0 Training loss: 0.2808 Explore P: 0.0109
# Episode: 868 Total reward: 199.0 Training loss: 0.5418 Explore P: 0.0109
# Episode: 869 Total reward: 199.0 Training loss: 0.2850 Explore P: 0.0108
# Episode: 870 Total reward: 199.0 Training loss: 0.4611 Explore P: 0.0108
# Episode: 871 Total reward: 199.0 Training loss: 0.2572 Explore P: 0.0108
# Episode: 872 Total reward: 199.0 Training loss: 0.7899 Explore P: 0.0108
# Episode: 873 Total reward: 199.0 Training loss: 0.7273 Explore P: 0.0108
# Episode: 874 Total reward: 199.0 Training loss: 0.5300 Explore P: 0.0108
# Episode: 875 Total reward: 199.0 Training loss: 0.9290 Explore P: 0.0108
# Episode: 876 Total reward: 199.0 Training loss: 0.2853 Explore P: 0.0107
# Episode: 877 Total reward: 199.0 Training loss: 0.4103 Explore P: 0.0107
# Episode: 878 Total reward: 199.0 Training loss: 52.4233 Explore P: 0.0107
# Episode: 879 Total reward: 199.0 Training loss: 0.4342 Explore P: 0.0107
# Episode: 880 Total reward: 199.0 Training loss: 81.2468 Explore P: 0.0107
# Episode: 881 Total reward: 199.0 Training loss: 0.3096 Explore P: 0.0107
# Episode: 882 Total reward: 199.0 Training loss: 0.5921 Explore P: 0.0107
# Episode: 883 Total reward: 199.0 Training loss: 185.3587 Explore P: 0.0106
# Episode: 884 Total reward: 199.0 Training loss: 0.4974 Explore P: 0.0106
# Episode: 885 Total reward: 199.0 Training loss: 0.4518 Explore P: 0.0106
# Episode: 886 Total reward: 199.0 Training loss: 0.3692 Explore P: 0.0106
# Episode: 887 Total reward: 199.0 Training loss: 0.3249 Explore P: 0.0106
# Episode: 888 Total reward: 199.0 Training loss: 0.3683 Explore P: 0.0106
# Episode: 889 Total reward: 199.0 Training loss: 0.2330 Explore P: 0.0106
# Episode: 890 Total reward: 199.0 Training loss: 218.6791 Explore P: 0.0106
# Episode: 891 Total reward: 199.0 Training loss: 0.2542 Explore P: 0.0105
# Episode: 892 Total reward: 199.0 Training loss: 0.2399 Explore P: 0.0105
# Episode: 893 Total reward: 199.0 Training loss: 0.2328 Explore P: 0.0105
# Episode: 894 Total reward: 199.0 Training loss: 0.2046 Explore P: 0.0105
# Episode: 895 Total reward: 199.0 Training loss: 0.1623 Explore P: 0.0105
# Episode: 896 Total reward: 199.0 Training loss: 0.3061 Explore P: 0.0105
# Episode: 897 Total reward: 199.0 Training loss: 0.1513 Explore P: 0.0105
# Episode: 898 Total reward: 199.0 Training loss: 0.4433 Explore P: 0.0105
# Episode: 899 Total reward: 199.0 Training loss: 0.2115 Explore P: 0.0105
# Episode: 900 Total reward: 199.0 Training loss: 0.1990 Explore P: 0.0105
# Episode: 901 Total reward: 199.0 Training loss: 0.3494 Explore P: 0.0104
# Episode: 902 Total reward: 199.0 Training loss: 0.1517 Explore P: 0.0104
# Episode: 903 Total reward: 199.0 Training loss: 0.2964 Explore P: 0.0104
# Episode: 904 Total reward: 199.0 Training loss: 0.4091 Explore P: 0.0104
# Episode: 905 Total reward: 199.0 Training loss: 0.2148 Explore P: 0.0104
# Episode: 906 Total reward: 199.0 Training loss: 0.2376 Explore P: 0.0104
# Episode: 907 Total reward: 199.0 Training loss: 0.1533 Explore P: 0.0104
# Episode: 908 Total reward: 199.0 Training loss: 0.1750 Explore P: 0.0104
# Episode: 909 Total reward: 199.0 Training loss: 0.1718 Explore P: 0.0104
# Episode: 910 Total reward: 199.0 Training loss: 0.2034 Explore P: 0.0104
# Episode: 911 Total reward: 199.0 Training loss: 0.3560 Explore P: 0.0104
# Episode: 912 Total reward: 199.0 Training loss: 0.2192 Explore P: 0.0104
# Episode: 913 Total reward: 199.0 Training loss: 164.9002 Explore P: 0.0104
# Episode: 914 Total reward: 199.0 Training loss: 0.2943 Explore P: 0.0103
# Episode: 915 Total reward: 199.0 Training loss: 0.1777 Explore P: 0.0103
# Episode: 916 Total reward: 180.0 Training loss: 0.1988 Explore P: 0.0103
# Episode: 917 Total reward: 199.0 Training loss: 0.1563 Explore P: 0.0103
# Episode: 918 Total reward: 127.0 Training loss: 0.3020 Explore P: 0.0103
# Episode: 919 Total reward: 199.0 Training loss: 0.3811 Explore P: 0.0103
# Episode: 920 Total reward: 179.0 Training loss: 0.2474 Explore P: 0.0103
# Episode: 921 Total reward: 153.0 Training loss: 177.1905 Explore P: 0.0103
# Episode: 922 Total reward: 199.0 Training loss: 0.2588 Explore P: 0.0103
# Episode: 923 Total reward: 199.0 Training loss: 0.1676 Explore P: 0.0103
# Episode: 924 Total reward: 199.0 Training loss: 0.3623 Explore P: 0.0103
# Episode: 925 Total reward: 199.0 Training loss: 0.1507 Explore P: 0.0103
# Episode: 926 Total reward: 199.0 Training loss: 0.1496 Explore P: 0.0103
# Episode: 927 Total reward: 199.0 Training loss: 0.1863 Explore P: 0.0103
# Episode: 928 Total reward: 199.0 Training loss: 0.1509 Explore P: 0.0103
# Episode: 929 Total reward: 199.0 Training loss: 0.1736 Explore P: 0.0103
# Episode: 930 Total reward: 199.0 Training loss: 0.1896 Explore P: 0.0103
# Episode: 931 Total reward: 199.0 Training loss: 0.0999 Explore P: 0.0103
# Episode: 932 Total reward: 199.0 Training loss: 255.6744 Explore P: 0.0102
# Episode: 933 Total reward: 199.0 Training loss: 0.3653 Explore P: 0.0102
# Episode: 934 Total reward: 199.0 Training loss: 0.1275 Explore P: 0.0102
# Episode: 935 Total reward: 199.0 Training loss: 0.1715 Explore P: 0.0102
# Episode: 936 Total reward: 199.0 Training loss: 0.1804 Explore P: 0.0102
# Episode: 937 Total reward: 199.0 Training loss: 0.0962 Explore P: 0.0102
# Episode: 938 Total reward: 199.0 Training loss: 0.1559 Explore P: 0.0102
# Episode: 939 Total reward: 199.0 Training loss: 0.0791 Explore P: 0.0102
# Episode: 940 Total reward: 199.0 Training loss: 0.1407 Explore P: 0.0102
# Episode: 941 Total reward: 199.0 Training loss: 0.1622 Explore P: 0.0102
# Episode: 942 Total reward: 199.0 Training loss: 0.2323 Explore P: 0.0102
# Episode: 943 Total reward: 199.0 Training loss: 0.2960 Explore P: 0.0102
# Episode: 944 Total reward: 199.0 Training loss: 274.6306 Explore P: 0.0102
# Episode: 945 Total reward: 199.0 Training loss: 0.3131 Explore P: 0.0102
# Episode: 946 Total reward: 199.0 Training loss: 0.2028 Explore P: 0.0102
# Episode: 947 Total reward: 199.0 Training loss: 0.2472 Explore P: 0.0102
# Episode: 948 Total reward: 199.0 Training loss: 0.1918 Explore P: 0.0102
# Episode: 949 Total reward: 97.0 Training loss: 0.3765 Explore P: 0.0102
# Episode: 950 Total reward: 86.0 Training loss: 0.3500 Explore P: 0.0102
# Episode: 951 Total reward: 70.0 Training loss: 0.1640 Explore P: 0.0102
# Episode: 952 Total reward: 55.0 Training loss: 0.4971 Explore P: 0.0102
# Episode: 953 Total reward: 53.0 Training loss: 0.4635 Explore P: 0.0102
# Episode: 954 Total reward: 50.0 Training loss: 0.4048 Explore P: 0.0102
# Episode: 955 Total reward: 65.0 Training loss: 0.3172 Explore P: 0.0102
# Episode: 956 Total reward: 100.0 Training loss: 0.1595 Explore P: 0.0102
# Episode: 957 Total reward: 89.0 Training loss: 0.1892 Explore P: 0.0102
# Episode: 958 Total reward: 52.0 Training loss: 0.2875 Explore P: 0.0102
# Episode: 959 Total reward: 31.0 Training loss: 0.3885 Explore P: 0.0102
# Episode: 960 Total reward: 25.0 Training loss: 0.4873 Explore P: 0.0102
# Episode: 961 Total reward: 29.0 Training loss: 0.3788 Explore P: 0.0102
# Episode: 962 Total reward: 46.0 Training loss: 0.6003 Explore P: 0.0102
# Episode: 963 Total reward: 41.0 Training loss: 0.1808 Explore P: 0.0102
# Episode: 964 Total reward: 40.0 Training loss: 0.4896 Explore P: 0.0102
# Episode: 965 Total reward: 22.0 Training loss: 287.8503 Explore P: 0.0102
# Episode: 966 Total reward: 17.0 Training loss: 0.7452 Explore P: 0.0102
# Episode: 967 Total reward: 13.0 Training loss: 0.8433 Explore P: 0.0102
# Episode: 968 Total reward: 41.0 Training loss: 0.5603 Explore P: 0.0102
# Episode: 969 Total reward: 30.0 Training loss: 0.3835 Explore P: 0.0102
# Episode: 970 Total reward: 31.0 Training loss: 0.5186 Explore P: 0.0102
# Episode: 971 Total reward: 17.0 Training loss: 0.3531 Explore P: 0.0102
# Episode: 972 Total reward: 21.0 Training loss: 0.4388 Explore P: 0.0102
# Episode: 973 Total reward: 31.0 Training loss: 0.5400 Explore P: 0.0102
# Episode: 974 Total reward: 16.0 Training loss: 0.4247 Explore P: 0.0102
# Episode: 975 Total reward: 14.0 Training loss: 0.6667 Explore P: 0.0102
# Episode: 976 Total reward: 25.0 Training loss: 0.3237 Explore P: 0.0102
# Episode: 977 Total reward: 22.0 Training loss: 0.5330 Explore P: 0.0102
# Episode: 978 Total reward: 15.0 Training loss: 0.5351 Explore P: 0.0102
# Episode: 979 Total reward: 15.0 Training loss: 0.7780 Explore P: 0.0102
# Episode: 980 Total reward: 16.0 Training loss: 0.5417 Explore P: 0.0102
# Episode: 981 Total reward: 14.0 Training loss: 0.8763 Explore P: 0.0102
# Episode: 982 Total reward: 13.0 Training loss: 0.5694 Explore P: 0.0102
# Episode: 983 Total reward: 22.0 Training loss: 356.5971 Explore P: 0.0102
# Episode: 984 Total reward: 19.0 Training loss: 262.9340 Explore P: 0.0102
# Episode: 985 Total reward: 10.0 Training loss: 0.7793 Explore P: 0.0102
# Episode: 986 Total reward: 16.0 Training loss: 0.7063 Explore P: 0.0102
# Episode: 987 Total reward: 16.0 Training loss: 0.8097 Explore P: 0.0102
# Episode: 988 Total reward: 12.0 Training loss: 332.8535 Explore P: 0.0102
# Episode: 989 Total reward: 18.0 Training loss: 692.5128 Explore P: 0.0102
# Episode: 990 Total reward: 12.0 Training loss: 0.8451 Explore P: 0.0102
# Episode: 991 Total reward: 16.0 Training loss: 324.3702 Explore P: 0.0102
# Episode: 992 Total reward: 27.0 Training loss: 0.4502 Explore P: 0.0102
# Episode: 993 Total reward: 49.0 Training loss: 0.2331 Explore P: 0.0102
# Episode: 994 Total reward: 34.0 Training loss: 0.4112 Explore P: 0.0102
# Episode: 995 Total reward: 84.0 Training loss: 657.5893 Explore P: 0.0102
# Episode: 996 Total reward: 34.0 Training loss: 0.3531 Explore P: 0.0102
# Episode: 997 Total reward: 20.0 Training loss: 316.1447 Explore P: 0.0102
# Episode: 998 Total reward: 53.0 Training loss: 0.3797 Explore P: 0.0101
# Episode: 999 Total reward: 77.0 Training loss: 0.5389 Explore P: 0.0101

# %% [markdown]
# ## Visualizing training
#
# Below I'll plot the total rewards for each episode. I'm plotting the rolling average too, in blue.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

def running_mean(x, N):
    cumsum = np.cumsum(np.insert(x, 0, 0)) 
    return (cumsum[N:] - cumsum[:-N]) / N

# %%
eps, rews = np.array(rewards_list).T
smoothed_rews = running_mean(rews, 10)
plt.plot(eps[-len(smoothed_rews):], smoothed_rews)
plt.plot(eps, rews, color='grey', alpha=0.3)
plt.xlabel('Episode')
plt.ylabel('Total Reward')

# %% [markdown]
# ## Testing
#
# Let's checkout how our trained agent plays the game.

# %%
test_episodes = 10
test_max_steps = 400
env.reset()
with tf.Session() as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    
    for ep in range(1, test_episodes):
        t = 0
        while t < test_max_steps:
            env.render() 
            
            # Get action from Q-network
            feed = {mainQN.inputs_: state.reshape((1, *state.shape))}
            Qs = sess.run(mainQN.output, feed_dict=feed)
            action = np.argmax(Qs)
            
            # Take action, get new state and reward
            next_state, reward, done, _ = env.step(action)
            
            if done:
                t = test_max_steps
                env.reset()
                # Take one random step to get the pole and cart moving
                state, reward, done, _ = env.step(env.action_space.sample())

            else:
                state = next_state
                t += 1
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\cartpole.ckpt
# [2017-08-22 00:39:01,309] Restoring parameters from checkpoints\cartpole.ckpt

# %%
env.close()

# %% [markdown]
# ## Extending this
#
# So, Cart-Pole is a pretty simple game. However, the same model can be used to train an agent to play something much more complicated like Pong or Space Invaders. Instead of a state like we're using here though, you'd want to use convolutional layers to get the state from the screen images.
#
# ![Deep Q-Learning Atari](assets/atari-network.png)
#
# I'll leave it as a challenge for you to use deep Q-learning to train an agent to play Atari games. Here's the original paper which will get you started: http://www.davidqiu.com:8888/research/nature14236.pdf.
